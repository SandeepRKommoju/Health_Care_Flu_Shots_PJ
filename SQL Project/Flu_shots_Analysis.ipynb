# %%
'''

This jupyter notebook will build a Data extract file that will be plugged into a BI tool 
to create a Flu Shots Dashboard.

Tables used:
1. Patients
2. Immunizations
3. Encounters

'''

# %%
'''

Dashboard must track below Metrics

1) Total % of patients getting flu shots stratified by
   a) Age
   b) Race
   c) County (On a Map)
   d) Overall
2) Running Total of Flu Shots over the course of 2022
3) Total number of Flu shots given in 2022
4) A list of Patients that show whether or not they received the flu shots

Conditions:
1) Patients must be active at the hospital.
2) Active Patients will have encounters in the past couple of years.

'''

# %%
# %load_ext sql

# %%
# %sql postgresql://postgres:password123@localhost:5433/postgres

# %%
# %%sql
#
# -- List all columns in the 'health_care' database
# SELECT
#     table_schema,
#     table_name,
#     string_agg(column_name, ', ') AS columns_list
# FROM information_schema.columns
# WHERE table_schema NOT IN ('pg_catalog', 'information_schema') -- exclude system schemas
# GROUP BY table_schema, table_name
# ORDER BY table_schema, table_name;
# Out:
#  * postgresql://postgres:***@localhost:5433/postgres
# 4 rows affected.
# [('health_care', 'conditions', 'code, encounter, patient, start, description, stop'),
#  ('health_care', 'encounters', 'payer_coverage, reasoncode, start, encounterclass, code, description, base_encounter_cost, total_claim_cost, id, stop, patient, organization, provider, payer'),
#  ('health_care', 'immunizations', 'encounter, patient, code, description, date'),
#  ('health_care', 'patients', 'ethnicity, gender, birthplace, first, birthdate, deathdate, fips, zip, lat, lon, healthcare_expenses, healthcare_coverage, income, address, city, id, state, county, ssn, drivers, passport, prefix, mrn, last, suffix, maiden, marital, race')]

# %%
'''
List all patients who had seasonal flu vaccine (code = 5302) in 2022. 
List only the details of the 1st seasonal flu vaccine.
Use CASE Statement to identify the patients who received flu shot in 2022.
'''

# %%
# %%sql
#
# select
#     p.id,
#     p.first,
#     p.last,
#     p.birthdate,
#     p.race,
#     p.county
# from health_care.patients as p
# limit 10;
# Out:
#  * postgresql://postgres:***@localhost:5433/postgres
# 10 rows affected.
# [('73d3ebe3-e656-b9de-fd61-88d370a86d51', 'Hedy', 'Von', datetime.date(1985, 9, 15), 'white', 'Middlesex County'),
#  ('cc53e99a-6715-603f-b074-eea93fe11e20', 'Adelina', 'Treutel', datetime.date(1961, 7, 26), 'white', 'Hampden County'),
#  ('15e61a30-618d-4b20-dd5d-5dc627fa6e4c', 'Artie', 'Cronin', datetime.date(2001, 12, 27), 'white', 'Worcester County'),
#  ('32a2188a-132e-4fd4-1a0e-3d532f4c4ea8', 'Lauryn', 'Wisozk', datetime.date(1958, 12, 17), 'white', 'Suffolk County'),
#  ('4adcad4e-1aa5-5601-4107-55953f484703', 'Dorthea', 'Reichel', datetime.date(1962, 6, 26), 'black', 'Norfolk County'),
#  ('52de8610-de40-203d-4bd6-cf06141fa864', 'Sherita', 'Orn', datetime.date(1975, 11, 8), 'white', 'Hampden County'),
#  ('154290c8-6729-fe33-d3b6-a66f04bb939e', 'Elenora', 'Raynor', datetime.date(1964, 10, 2), 'white', 'Barnstable County'),
#  ('10d940ae-7114-8bcf-50f9-2bfd5354ff41', 'Rebeca', 'Mayer', datetime.date(1962, 5, 17), 'white', 'Essex County'),
#  ('ac63da4a-893a-1d3c-aa93-fb78c8da3d95', 'Casie', 'Hilpert', datetime.date(1971, 4, 21), 'white', 'Norfolk County'),
#  ('bcb267a1-09ab-7082-96bd-81b867c68da7', 'Arline', 'Jenkins', datetime.date(1983, 10, 4), 'white', 'Plymouth County')]

# %%
# %%sql
#
# /*
# CTE to show Active patients in the hospital.
#
# Active patients:
# 1) Patients who are ALIVE
# 2) Patients who are still visiting the hospital since 2020.
# 3) Age of patient must be > 6 Months
#
# patient who had an encounter in 2022.
#
# Use the 'deathdate' field in 'patients' table
# 'encounters' table
# */
#
# -- CTE to show active patients
# WITH active_patients AS (
#     select distinct(e.patient)
#     from health_care.encounters as e
#     join health_care.patients as p
#     on e.patient = p.id
#     where start between '2020-01-01 00:00' AND '2022-12-31 23:59'
#     and p.deathdate is null
#     and extract(month from age('2022-12-31 23:59', p.birthdate)) > 6
# ),
#
# -- CTE to show patients who had their earliest flu shot in 2022
# flu_shot_2022 AS (
#     SELECT patient, MIN(date) AS earliest_flu_shot_in_2022
#     FROM health_care.immunizations
#     WHERE code = '5302'
#     AND date BETWEEN '2022-01-01 00:00' AND '2022-12-31 23:59'
#     GROUP BY patient
# )
#
# select
#     p.id,
#     p.first,
#     p.last,
#     p.birthdate,
#     p.race,
#     p.county,
#     flu.patient,
#     flu.earliest_flu_shot_in_2022,
#     case when flu.patient is not null then 1
#     else 0
#     end as received_flu_shot_2022
# from health_care.patients as p
# left join flu_shot_2022 as flu
# on p.id = flu.patient
# where 1 = 1 -- place holder
# and p.id in (select patient from active_patients)
# Out:
#  * postgresql://postgres:***@localhost:5433/postgres
# 4084 rows affected.
# [('10d940ae-7114-8bcf-50f9-2bfd5354ff41', 'Rebeca', 'Mayer', datetime.date(1962, 5, 17), 'white', 'Essex County', '10d940ae-7114-8bcf-50f9-2bfd5354ff41', datetime.datetime(2022, 7, 14, 13, 32), 1),
#  ('ac63da4a-893a-1d3c-aa93-fb78c8da3d95', 'Casie', 'Hilpert', datetime.date(1971, 4, 21), 'white', 'Norfolk County', 'ac63da4a-893a-1d3c-aa93-fb78c8da3d95', datetime.datetime(2022, 4, 27, 22, 58, 31), 1),
#  ('91f57fef-7f76-6f23-1c4b-eb973e556ce3', 'Rosario', 'Ruecker', datetime.date(1983, 5, 27), 'white', 'Norfolk County', '91f57fef-7f76-6f23-1c4b-eb973e556ce3', datetime.datetime(2022, 4, 2, 3, 37, 22), 1),
#  ('ea264f1c-04e6-c056-54e7-5d5c63a6fc4c', 'Natosha', "O'Connell", datetime.date(2018, 2, 9), 'white', 'Hampshire County', 'ea264f1c-04e6-c056-54e7-5d5c63a6fc4c', datetime.datetime(2022, 1, 15, 6, 51, 7), 1),
#  ('6cc89ec7-8e4a-536e-356a-05d89f3fac7a', 'Dakota', 'Kihn', datetime.date(2010, 1, 31), 'white', 'Worcester County', '6cc89ec7-8e4a-536e-356a-05d89f3fac7a', datetime.datetime(2022, 2, 21, 7, 12, 55), 1),
#  ('13ed3a20-35fa-13c7-7864-f2a0b7f8a241', 'Deanne', 'Champlin', datetime.date(1965, 2, 19), 'asian', 'Middlesex County', '13ed3a20-35fa-13c7-7864-f2a0b7f8a241', datetime.datetime(2022, 4, 1, 14, 57, 48), 1),
#  ('ab32a95b-48fd-6cb8-284c-232de5ba888a', 'Novella', 'Buckridge', datetime.date(2003, 2, 3), 'white', 'Franklin County', 'ab32a95b-48fd-6cb8-284c-232de5ba888a', datetime.datetime(2022, 4, 4, 15, 17, 21), 1),
#  ('70de7978-7264-c9a9-1bc2-1b97d899c1e7', 'Evia', 'Lemke', datetime.date(1976, 3, 28), 'white', 'Middlesex County', '70de7978-7264-c9a9-1bc2-1b97d899c1e7', datetime.datetime(2022, 4, 17, 15, 36, 55), 1),
#  ('9cf72380-ea4b-a6a4-1d23-7ad351bdefc1', 'Jone', 'Heidenreich', datetime.date(1964, 5, 19), 'black', 'Plymouth County', '9cf72380-ea4b-a6a4-1d23-7ad351bdefc1', datetime.datetime(2022, 1, 25, 22, 20, 28), 1),
#  ('e61368d0-7dbb-9514-2d9b-a6ad7bba5620', 'Karren', 'Streich', datetime.date(2008, 1, 6), 'white', 'Middlesex County', 'e61368d0-7dbb-9514-2d9b-a6ad7bba5620', datetime.datetime(2022, 2, 6, 19, 24, 26), 1),
#  ('748186be-1c5e-5f8c-8498-25d83a9f3b6f', 'Carrol', 'Yundt', datetime.date(1968, 4, 3), 'white', 'Norfolk County', None, None, 0),
#  ('df21951d-adc3-b74f-aa41-447077181383', 'Madelyn', 'Morar', datetime.date(1953, 1, 9), 'white', 'Worcester County', 'df21951d-adc3-b74f-aa41-447077181383', datetime.datetime(2022, 7, 22, 10, 32, 56), 1),
#  ('b97a1479-9cee-1b72-7c37-f5a4ee5a2cbe', 'Janelle', 'Jacobi', datetime.date(1970, 4, 7), 'white', 'Bristol County', 'b97a1479-9cee-1b72-7c37-f5a4ee5a2cbe', datetime.datetime(2022, 6, 7, 12, 11, 45), 1),
#  ('a86ecde5-0f1d-a42a-ddf7-0f2f203cab05', 'Tamisha', 'Windler', datetime.date(2004, 2, 25), 'white', 'Essex County', 'a86ecde5-0f1d-a42a-ddf7-0f2f203cab05', datetime.datetime(2022, 4, 20, 17, 58, 16), 1),
#  ('4be71f38-271b-542a-c0cb-280a7dafb3b4', 'Theresia', 'Hettinger', datetime.date(1985, 4, 19), 'white', 'Bristol County', '4be71f38-271b-542a-c0cb-280a7dafb3b4', datetime.datetime(2022, 1, 7, 8, 0, 34), 1),
#  ('e51d646e-94b7-718e-a5d7-a4ec51a4cf63', 'Jackqueline', 'Sporer', datetime.date(2015, 1, 28), 'white', 'Essex County', 'e51d646e-94b7-718e-a5d7-a4ec51a4cf63', datetime.datetime(2022, 1, 19, 15, 13, 10), 1),
#  ('71382378-ec0e-1a52-b74d-ee147e1ccbda', 'Violet', 'Monahan', datetime.date(1971, 2, 18), 'white', 'Hampden County', '71382378-ec0e-1a52-b74d-ee147e1ccbda', datetime.datetime(2022, 3, 31, 8, 30, 28), 1),
#  ('7cf1df4a-2482-8236-c1f9-d1a0ac39e6b5', 'Gerda', 'Berge', datetime.date(2007, 2, 24), 'white', 'Worcester County', '7cf1df4a-2482-8236-c1f9-d1a0ac39e6b5', datetime.datetime(2022, 4, 2, 16, 55, 49), 1),
#  ('5e502da4-8c7e-4a11-5614-8051b2b65f47', 'Jeniffer', 'Herzog', datetime.date(2021, 3, 15), 'white', 'Plymouth County', None, None, 0),
#  ('7de0eb41-caec-040a-c380-39ee808e7faa', 'Loralee', 'Parker', datetime.date(1980, 3, 19), 'white', 'Hampshire County', '7de0eb41-caec-040a-c380-39ee808e7faa', datetime.datetime(2022, 3, 30, 15, 56, 28), 1),
#  ('74312675-9872-408a-4fda-61bd7c032ab1', 'Glennie', 'Rosenbaum', datetime.date(2006, 2, 6), 'white', 'Middlesex County', '74312675-9872-408a-4fda-61bd7c032ab1', datetime.datetime(2022, 4, 19, 0, 41, 45), 1),
#  ('1ea15089-9abd-4018-68d6-6deb2b2fbd94', 'Susie', 'Lind', datetime.date(1960, 5, 5), 'black', 'Worcester County', '1ea15089-9abd-4018-68d6-6deb2b2fbd94', datetime.datetime(2022, 7, 15, 4, 42, 2), 1),
#  ('d02f5d56-2741-1267-c1b0-0e3e4fd8a972', 'Virginia', 'Bauch', datetime.date(2002, 1, 6), 'other', 'Middlesex County', 'd02f5d56-2741-1267-c1b0-0e3e4fd8a972', datetime.datetime(2022, 3, 13, 9, 52, 42), 1),
#  ('aef118e5-f120-6298-0de2-cbb64962589c', 'Cheryll', 'Mills', datetime.date(2019, 2, 15), 'white', 'Norfolk County', 'aef118e5-f120-6298-0de2-cbb64962589c', datetime.datetime(2022, 1, 22, 5, 58, 16), 1),
#  ('d0392566-245b-2c04-68d3-907c1fd28770', 'Chrystal', 'Hyatt', datetime.date(1987, 3, 10), 'white', 'Middlesex County', 'd0392566-245b-2c04-68d3-907c1fd28770', datetime.datetime(2022, 5, 31, 14, 49, 11), 1),
#  ('25a1c6fc-3450-6997-3e3d-c64403a43c29', 'Maryln', 'Legros', datetime.date(1949, 5, 19), 'white', 'Norfolk County', '25a1c6fc-3450-6997-3e3d-c64403a43c29', datetime.datetime(2022, 9, 29, 23, 39, 44), 1),
#  ('c7d380b3-e4ef-abdb-2a54-7342e19f3847', 'Dana', 'Bogisich', datetime.date(1968, 1, 29), 'black', 'Bristol County', 'c7d380b3-e4ef-abdb-2a54-7342e19f3847', datetime.datetime(2022, 10, 3, 10, 36, 10), 1),
#  ('9f4b455f-97ef-e125-2658-1f82d7c676a0', 'Elsy', 'Glover', datetime.date(1954, 1, 22), 'white', 'Hampden County', '9f4b455f-97ef-e125-2658-1f82d7c676a0', datetime.datetime(2022, 12, 17, 1, 35, 51), 1),
#  ('7666f6ef-f219-03a4-ff5f-0222dfa0662d', 'Clotilde', 'Walter', datetime.date(1955, 5, 14), 'white', 'Norfolk County', '7666f6ef-f219-03a4-ff5f-0222dfa0662d', datetime.datetime(2022, 8, 20, 8, 37, 31), 1),
#  ('ab7da3f2-f683-7881-c1c6-2a526da9ff1e', 'María Eugenia', 'Pedroza', datetime.date(2014, 1, 5), 'white', 'Essex County', 'ab7da3f2-f683-7881-c1c6-2a526da9ff1e', datetime.datetime(2022, 1, 2, 20, 22, 49), 1),
#  ('d04392a3-8d29-6513-3220-b2d22e759c54', 'Galina', 'Pollich', datetime.date(1955, 3, 3), 'white', 'Plymouth County', 'd04392a3-8d29-6513-3220-b2d22e759c54', datetime.datetime(2022, 6, 10, 0, 24, 46), 1),
#  ('c984eb85-ca0c-bad4-9507-2d1bcf0e95a6', 'Lavelle', 'Moore', datetime.date(1974, 3, 12), 'white', 'Suffolk County', 'c984eb85-ca0c-bad4-9507-2d1bcf0e95a6', datetime.datetime(2022, 4, 6, 3, 17, 6), 1),
#  ('da5673e9-e465-ce9b-e819-3a7ef29b1c06', 'Maren', 'Volkman', datetime.date(1979, 2, 4), 'white', 'Norfolk County', 'da5673e9-e465-ce9b-e819-3a7ef29b1c06', datetime.datetime(2022, 2, 20, 22, 30, 7), 1),
#  ('fbdb9ade-dbe5-afcd-0d3d-c54e4ab4260e', 'Ona', 'Lemke', datetime.date(1964, 3, 22), 'white', 'Bristol County', 'fbdb9ade-dbe5-afcd-0d3d-c54e4ab4260e', datetime.datetime(2022, 5, 9, 1, 19, 19), 1),
#  ('0890bbbe-130a-818a-bf23-d521803c3c77', 'Antonietta', 'Williamson', datetime.date(1981, 2, 10), 'asian', 'Essex County', '0890bbbe-130a-818a-bf23-d521803c3c77', datetime.datetime(2022, 6, 7, 21, 1, 32), 1),
#  ('1564b50e-4230-a8ef-967a-977738a0620d', 'Rosena', 'Eichmann', datetime.date(2007, 5, 3), 'white', 'Middlesex County', '1564b50e-4230-a8ef-967a-977738a0620d', datetime.datetime(2022, 6, 9, 20, 40, 20), 1),
#  ('1e060e9e-e23e-f0bb-9725-bbd0b5a16699', 'Dell', 'Parker', datetime.date(1974, 2, 22), 'white', 'Plymouth County', '1e060e9e-e23e-f0bb-9725-bbd0b5a16699', datetime.datetime(2022, 3, 18, 13, 43, 28), 1),
#  ('0a7dae52-d869-6afb-93fb-61d25f6fcca6', 'Annabel', 'Ebert', datetime.date(1984, 1, 12), 'white', 'Hampden County', None, None, 0),
#  ('8b44ee06-b037-b858-c99d-ec0c0521cacc', 'Daniela', 'Armendáriz', datetime.date(2010, 4, 20), 'white', 'Worcester County', '8b44ee06-b037-b858-c99d-ec0c0521cacc', datetime.datetime(2022, 5, 10, 8, 27, 40), 1),
#  ('274f03c0-468d-1fdf-a517-e4e040afe593', 'Georgine', 'Stracke', datetime.date(1935, 3, 26), 'white', 'Essex County', '274f03c0-468d-1fdf-a517-e4e040afe593', datetime.datetime(2022, 10, 26, 3, 12, 14), 1),
#  ('79a9798a-fb18-ca17-2b03-700c1c2f1451', 'Lynnette', 'Morissette', datetime.date(2001, 3, 2), 'white', 'Worcester County', None, None, 0),
#  ('efe2ff22-cf7d-0a4e-3403-fc953ae80234', 'Dorothy', 'Hodkiewicz', datetime.date(1998, 4, 3), 'white', 'Essex County', 'efe2ff22-cf7d-0a4e-3403-fc953ae80234', datetime.datetime(2022, 9, 23, 22, 50, 42), 1),
#  ('f6110547-82b6-ec8a-9306-ad3c0f71e471', 'Margarett', 'Lemke', datetime.date(1956, 5, 16), 'white', 'Hampden County', 'f6110547-82b6-ec8a-9306-ad3c0f71e471', datetime.datetime(2022, 8, 18, 3, 49, 39), 1),
#  ('3aa9daff-1904-281e-6b05-d7f1366d046b', 'Jammie', 'Donnelly', datetime.date(1978, 5, 23), 'asian', 'Norfolk County', '3aa9daff-1904-281e-6b05-d7f1366d046b', datetime.datetime(2022, 3, 30, 0, 37, 58), 1),
#  ('927aaeae-53c9-3ffd-c3b4-af68473def59', 'Danette', 'Heller', datetime.date(1964, 3, 1), 'white', 'Barnstable County', '927aaeae-53c9-3ffd-c3b4-af68473def59', datetime.datetime(2022, 3, 6, 20, 11, 20), 1),
#  ('0e0fe679-8536-4135-4aa9-2c6bbfd41807', 'Lavelle', 'Ledner', datetime.date(1945, 4, 7), 'white', 'Middlesex County', '0e0fe679-8536-4135-4aa9-2c6bbfd41807', datetime.datetime(2022, 12, 25, 0, 5, 49), 1),
#  ('4c66bb54-c465-c0e6-cc40-4ca0c3501b67', 'Marget', 'Boehm', datetime.date(2002, 4, 28), 'white', 'Hampden County', '4c66bb54-c465-c0e6-cc40-4ca0c3501b67', datetime.datetime(2022, 7, 3, 17, 23), 1),
#  ('4a5e431e-8b8d-3add-0120-21f3d9255d17', 'Assunta', 'Zboncak', datetime.date(1978, 5, 15), 'white', 'Essex County', '4a5e431e-8b8d-3add-0120-21f3d9255d17', datetime.datetime(2022, 5, 30, 10, 6, 49), 1),
#  ('4691fb06-22c9-7b4f-d8b2-57fa3ec152bb', 'Lizbeth', 'Shields', datetime.date(1976, 5, 22), 'white', 'Norfolk County', '4691fb06-22c9-7b4f-d8b2-57fa3ec152bb', datetime.datetime(2022, 12, 18, 1, 10, 27), 1),
#  ('763e3aef-4915-3842-9506-cfc2b250e8af', 'Elsa', 'Nazario', datetime.date(2017, 5, 12), 'black', 'Essex County', '763e3aef-4915-3842-9506-cfc2b250e8af', datetime.datetime(2022, 4, 23, 5, 45, 7), 1),
#  ('01ecab1c-e0ea-3119-8a95-48b756c47431', 'Victoria', 'Hammes', datetime.date(1962, 5, 19), 'white', 'Plymouth County', '01ecab1c-e0ea-3119-8a95-48b756c47431', datetime.datetime(2022, 8, 21, 4, 3, 40), 1),
#  ('ecd4e774-97fd-e40f-a2b1-3437a507f21b', 'Hollie', 'Adams', datetime.date(1968, 5, 11), 'asian', 'Essex County', 'ecd4e774-97fd-e40f-a2b1-3437a507f21b', datetime.datetime(2022, 11, 19, 9, 23, 1), 1),
#  ('a1e7a69a-cc07-10f2-8b30-904d3e7daa66', 'Marlin', 'Mertz', datetime.date(1997, 5, 18), 'white', 'Worcester County', 'a1e7a69a-cc07-10f2-8b30-904d3e7daa66', datetime.datetime(2022, 8, 21, 12, 59, 33), 1),
#  ('df50622a-60c6-1ff4-f061-b3faa2fcf3a8', 'Waneta', 'Beahan', datetime.date(1977, 1, 12), 'white', 'Hampden County', 'df50622a-60c6-1ff4-f061-b3faa2fcf3a8', datetime.datetime(2022, 3, 31, 4, 58, 47), 1),
#  ('9c1bf553-c57b-1222-86a3-c797b974d322', 'Jenee', 'Zieme', datetime.date(1996, 5, 15), 'white', 'Middlesex County', '9c1bf553-c57b-1222-86a3-c797b974d322', datetime.datetime(2022, 4, 6, 9, 25), 1),
#  ('858e1761-519d-61e4-76de-6aec5a83fed2', 'Eula', 'Veum', datetime.date(1984, 3, 1), 'white', 'Middlesex County', None, None, 0),
#  ('eae22690-e126-4aa7-26f4-fc588863f53b', 'Leonor', 'Mayer', datetime.date(1988, 3, 25), 'white', 'Suffolk County', 'eae22690-e126-4aa7-26f4-fc588863f53b', datetime.datetime(2022, 6, 10, 9, 15, 8), 1),
#  ('16121573-0c83-5f21-e4b7-71a4a3acb0f9', 'Lauran', 'Schuster', datetime.date(2000, 3, 10), 'white', 'Middlesex County', '16121573-0c83-5f21-e4b7-71a4a3acb0f9', datetime.datetime(2022, 5, 13, 12, 1, 55), 1),
#  ('ba178fc5-2e42-6551-12b2-a651e580ef57', 'Fredda', 'Kunze', datetime.date(1979, 2, 4), 'black', 'Norfolk County', 'ba178fc5-2e42-6551-12b2-a651e580ef57', datetime.datetime(2022, 6, 12, 9, 40, 32), 1),
#  ('2dc95eae-76c3-9a13-4e23-eeb1127d6b76', 'Dorene', 'Kassulke', datetime.date(2001, 5, 20), 'white', 'Hampshire County', '2dc95eae-76c3-9a13-4e23-eeb1127d6b76', datetime.datetime(2022, 8, 1, 5, 19, 33), 1),
#  ('3b9cd8c5-cdf7-3f10-afae-d8589b9f4b28', 'Logan', 'Graham', datetime.date(1965, 3, 21), 'white', 'Essex County', '3b9cd8c5-cdf7-3f10-afae-d8589b9f4b28', datetime.datetime(2022, 5, 1, 12, 34), 1),
#  ('d2eebfcb-c97e-cc99-70fc-7b962bb6eaf3', 'Alessandra', 'Veum', datetime.date(1995, 3, 18), 'white', 'Franklin County', None, None, 0),
#  ('3e1acc8c-e101-d8ce-ab0d-6449b9ee91a0', 'Myrle', 'Baumbach', datetime.date(1972, 1, 6), 'white', 'Norfolk County', '3e1acc8c-e101-d8ce-ab0d-6449b9ee91a0', datetime.datetime(2022, 2, 17, 17, 46, 29), 1),
#  ('2809cb04-9865-8f80-7fcc-45c5c9f7e8b6', 'Jaleesa', 'Goyette', datetime.date(1989, 4, 26), 'white', 'Norfolk County', '2809cb04-9865-8f80-7fcc-45c5c9f7e8b6', datetime.datetime(2022, 8, 18, 3, 10, 10), 1),
#  ('148e8316-b921-e8ca-8461-46aca15ecd52', 'Susanna', 'Wilkinson', datetime.date(2003, 3, 3), 'white', 'Worcester County', '148e8316-b921-e8ca-8461-46aca15ecd52', datetime.datetime(2022, 5, 3, 6, 12, 30), 1),
#  ('639c43dd-b285-3578-16c7-5e03247860da', 'Oneida', 'Erdman', datetime.date(2002, 5, 12), 'white', 'Middlesex County', '639c43dd-b285-3578-16c7-5e03247860da', datetime.datetime(2022, 7, 18, 1, 17, 16), 1),
#  ('ea7247e1-9b35-a01d-5876-c8775bfc149f', 'Louie', 'Streich', datetime.date(2021, 5, 16), 'white', 'Bristol County', 'ea7247e1-9b35-a01d-5876-c8775bfc149f', datetime.datetime(2022, 1, 23, 17, 22, 19), 1),
#  ('6ef6de74-e729-5063-65ff-e6ae09b403b8', 'Stefany', 'Heathcote', datetime.date(1957, 4, 9), 'white', 'Middlesex County', '6ef6de74-e729-5063-65ff-e6ae09b403b8', datetime.datetime(2022, 8, 9, 14, 3, 45), 1),
#  ('bc800e4d-ecd6-6a9c-cb7f-7b56c13fa0b7', 'Irena', 'Kautzer', datetime.date(1970, 1, 21), 'white', 'Norfolk County', 'bc800e4d-ecd6-6a9c-cb7f-7b56c13fa0b7', datetime.datetime(2022, 9, 28, 18, 17, 33), 1),
#  ('2f72698b-8c80-1160-d261-628c3e7e29d0', 'Mittie', 'Zemlak', datetime.date(1984, 3, 19), 'asian', 'Middlesex County', '2f72698b-8c80-1160-d261-628c3e7e29d0', datetime.datetime(2022, 4, 5, 1, 12, 8), 1),
#  ('b06bb6a3-7b36-e3e7-98f4-4b1411afe695', 'Gwenn', 'Daugherty', datetime.date(2022, 4, 6), 'white', 'Middlesex County', 'b06bb6a3-7b36-e3e7-98f4-4b1411afe695', datetime.datetime(2022, 12, 15, 2, 8, 14), 1),
#  ('207aeaa0-480b-cb18-fe90-37b89123da99', 'Lelah', 'Kohler', datetime.date(2004, 3, 28), 'white', 'Middlesex County', None, None, 0),
#  ('1f928593-6c75-5f11-2d6f-4ac6e1dd5923', 'Roxy', 'Hammes', datetime.date(1972, 2, 2), 'white', 'Worcester County', '1f928593-6c75-5f11-2d6f-4ac6e1dd5923', datetime.datetime(2022, 3, 30, 10, 37, 31), 1),
#  ('300ce38c-3f84-2322-7ca6-2bf3cfdda30f', 'Stephania', 'Conn', datetime.date(1970, 2, 1), 'white', 'Middlesex County', '300ce38c-3f84-2322-7ca6-2bf3cfdda30f', datetime.datetime(2022, 2, 14, 6, 26, 10), 1),
#  ('a5d6dca8-4c81-a30b-2317-611da595888c', 'Marcene', 'Schneider', datetime.date(2022, 2, 17), 'white', 'Bristol County', 'a5d6dca8-4c81-a30b-2317-611da595888c', datetime.datetime(2022, 10, 27, 16, 35, 34), 1),
#  ('7d834e7a-e311-b72c-4c83-84ea5a28396f', 'Malena', 'Carter', datetime.date(1962, 2, 1), 'white', 'Middlesex County', '7d834e7a-e311-b72c-4c83-84ea5a28396f', datetime.datetime(2022, 3, 31, 13, 38, 25), 1),
#  ('7b3e9b92-5520-e656-549a-06245a840327', 'Stephany', 'Moen', datetime.date(1944, 3, 21), 'black', 'Suffolk County', '7b3e9b92-5520-e656-549a-06245a840327', datetime.datetime(2022, 9, 6, 16, 46, 46), 1),
#  ('31556789-ecaf-e1bb-2ca5-badd6e1f6774', 'Deandrea', 'Maggio', datetime.date(1971, 4, 24), 'white', 'Barnstable County', '31556789-ecaf-e1bb-2ca5-badd6e1f6774', datetime.datetime(2022, 4, 30, 10, 17, 42), 1),
#  ('2910d17d-4416-3d4f-19c6-5fc2ad6fcb63', 'Paris', 'Weimann', datetime.date(1986, 4, 23), 'white', 'Worcester County', '2910d17d-4416-3d4f-19c6-5fc2ad6fcb63', datetime.datetime(2022, 3, 30, 18, 39, 49), 1),
#  ('6b5645c2-7453-ecae-0e39-a1dad7eb0ac0', 'Jeanmarie', 'Satterfield', datetime.date(1993, 4, 27), 'white', 'Hampden County', '6b5645c2-7453-ecae-0e39-a1dad7eb0ac0', datetime.datetime(2022, 4, 5, 7, 50, 15), 1),
#  ('ab178f03-52d1-ead4-51bb-128b1797afdb', 'Dania', 'Lesch', datetime.date(1971, 4, 26), 'white', 'Suffolk County', 'ab178f03-52d1-ead4-51bb-128b1797afdb', datetime.datetime(2022, 6, 28, 4, 16, 55), 1),
#  ('2fe32c7e-7e4d-1320-2453-24da72eba4f4', 'Teofila', 'Collier', datetime.date(1966, 3, 26), 'white', 'Plymouth County', '2fe32c7e-7e4d-1320-2453-24da72eba4f4', datetime.datetime(2022, 4, 30, 21, 8, 22), 1),
#  ('deed4726-f0a9-fe86-3866-74af74e9b232', 'Maryetta', 'Quigley', datetime.date(1997, 4, 4), 'asian', 'Hampden County', 'deed4726-f0a9-fe86-3866-74af74e9b232', datetime.datetime(2022, 6, 10, 16, 50, 35), 1),
#  ('31f7d25b-d787-045b-2e32-ca13a82e3a10', 'Margy', "O'Keefe", datetime.date(1992, 3, 4), 'white', 'Essex County', '31f7d25b-d787-045b-2e32-ca13a82e3a10', datetime.datetime(2022, 6, 2, 6, 10, 9), 1),
#  ('805da1a0-1c7c-10f7-ed7b-66cf1dfa64a5', 'Kami', 'McDermott', datetime.date(1969, 1, 4), 'white', 'Bristol County', '805da1a0-1c7c-10f7-ed7b-66cf1dfa64a5', datetime.datetime(2022, 1, 23, 0, 44, 21), 1),
#  ('e55ffaf5-a790-242c-bc80-54b43a5fa6b5', 'Thuy', 'Fadel', datetime.date(1984, 1, 19), 'white', 'Essex County', None, None, 0),
#  ('5e915b91-cbe8-e808-975a-70feedeb6ee1', 'Shavonda', 'Rippin', datetime.date(1979, 4, 1), 'white', 'Hampden County', '5e915b91-cbe8-e808-975a-70feedeb6ee1', datetime.datetime(2022, 7, 31, 18, 34, 52), 1),
#  ('ea482e58-56d3-c472-b6fc-f3b504fceb25', 'Charisse', 'Schaefer', datetime.date(2006, 5, 6), 'black', 'Worcester County', 'ea482e58-56d3-c472-b6fc-f3b504fceb25', datetime.datetime(2022, 6, 19, 6, 16, 5), 1),
#  ('92ac83d1-8aa9-1fcf-9eef-f2e944b347f3', 'Flo', 'Larkin', datetime.date(1962, 4, 29), 'white', 'Hampshire County', '92ac83d1-8aa9-1fcf-9eef-f2e944b347f3', datetime.datetime(2022, 6, 26, 8, 47, 4), 1),
#  ('75eee346-f5bd-c9e7-315e-2a96e79d7fda', 'Verda', 'Brown', datetime.date(1993, 4, 13), 'white', 'Essex County', None, None, 0),
#  ('899027af-f546-f724-3055-dbe8c970beb6', 'Keiko', 'Denesik', datetime.date(2012, 4, 1), 'white', 'Middlesex County', '899027af-f546-f724-3055-dbe8c970beb6', datetime.datetime(2022, 4, 10, 7, 56, 34), 1),
#  ('6fbd39c2-8a69-92b5-a024-397356a39911', 'Aurora', 'Langosh', datetime.date(1983, 2, 14), 'white', 'Norfolk County', None, None, 0),
#  ('38158e29-3883-5982-f5da-a7912aa2bf7f', 'Teresa', 'Pantoja', datetime.date(2008, 4, 19), 'white', 'Essex County', '38158e29-3883-5982-f5da-a7912aa2bf7f', datetime.datetime(2022, 5, 22, 1, 39, 16), 1),
#  ('adc0f355-9792-3a8e-08ae-cae58d5aaad1', 'Shelia', 'Stiedemann', datetime.date(1969, 5, 20), 'white', 'Barnstable County', 'adc0f355-9792-3a8e-08ae-cae58d5aaad1', datetime.datetime(2022, 7, 27, 5, 13, 16), 1),
#  ('15f3ff72-d63c-f21d-c191-0e77653e898a', 'Leta', 'Durgan', datetime.date(2011, 5, 17), 'white', 'Worcester County', '15f3ff72-d63c-f21d-c191-0e77653e898a', datetime.datetime(2022, 6, 1, 3, 16, 36), 1),
#  ('5a228d3b-70c5-c747-4685-48583436d9bb', 'Brandie', 'Boyer', datetime.date(1990, 5, 2), 'white', 'Middlesex County', '5a228d3b-70c5-c747-4685-48583436d9bb', datetime.datetime(2022, 3, 31, 1, 4, 12), 1),
#  ('9e22c7a6-8a0f-4ceb-1c2b-ec38dc3e9227', 'Pearl', 'Hessel', datetime.date(1995, 5, 31), 'white', 'Bristol County', None, None, 0),
#  ('97a57485-7038-8432-cd54-2b1a1af9609d', 'Yvone', 'Bergnaum', datetime.date(1988, 2, 18), 'white', 'Franklin County', '97a57485-7038-8432-cd54-2b1a1af9609d', datetime.datetime(2022, 7, 15, 0, 29, 54), 1),
#  ('80da601d-dc36-ddc8-c7d9-f832469cbd07', 'Hermine', 'Wolf', datetime.date(2002, 5, 23), 'white', 'Franklin County', None, None, 0),
#  ('2b1e4fc5-318b-ea23-67e7-84a82d862b34', 'Adaline', 'Crist', datetime.date(1976, 3, 6), 'white', 'Essex County', '2b1e4fc5-318b-ea23-67e7-84a82d862b34', datetime.datetime(2022, 7, 30, 14, 37, 30), 1),
#  ('6af866f6-9bac-c5a9-80a1-73397882b761', 'Devorah', 'Satterfield', datetime.date(1922, 1, 7), 'native', 'Suffolk County', '6af866f6-9bac-c5a9-80a1-73397882b761', datetime.datetime(2022, 10, 22, 14, 23, 20), 1),
#  ('4ac8252c-095d-3193-4ccc-b5b587c5cd6f', 'Violet', 'Bayer', datetime.date(1993, 5, 24), 'white', 'Suffolk County', None, None, 0),
#  ('a361788f-cbf2-7337-d329-dfdeca56566f', 'Bridget', 'Borer', datetime.date(1981, 2, 1), 'white', 'Essex County', None, None, 0),
#  ('622bec0b-0656-806b-4d0b-2a7ce05c1e31', 'Coralie', 'Franecki', datetime.date(1992, 4, 9), 'white', 'Plymouth County', '622bec0b-0656-806b-4d0b-2a7ce05c1e31', datetime.datetime(2022, 7, 14, 8, 28, 41), 1),
#  ('7126b099-e2d6-a0f4-42cc-49b1d849ae74', 'Sofia', 'Guerra', datetime.date(1994, 1, 30), 'white', 'Middlesex County', '7126b099-e2d6-a0f4-42cc-49b1d849ae74', datetime.datetime(2022, 4, 10, 20, 49, 1), 1),
#  ('575a409d-21a9-a833-04ab-3a0f19a03124', 'Lindsay', 'Fisher', datetime.date(2019, 5, 6), 'white', 'Middlesex County', '575a409d-21a9-a833-04ab-3a0f19a03124', datetime.datetime(2022, 4, 11, 23, 26, 10), 1),
#  ('bb8d3c0d-78f6-747e-bd03-9de9efd98a21', 'Merrie', 'Schinner', datetime.date(2017, 1, 14), 'white', 'Worcester County', None, None, 0),
#  ('0e460b0a-67ce-fbb5-554f-ceff1cb5a989', 'Markita', 'Grimes', datetime.date(1975, 1, 30), 'white', 'Suffolk County', '0e460b0a-67ce-fbb5-554f-ceff1cb5a989', datetime.datetime(2022, 8, 12, 4, 8, 55), 1),
#  ('20984f1d-7770-6f6f-dc8d-f65f7b5802dd', 'Karey', 'Runolfsdottir', datetime.date(1969, 1, 15), 'white', 'Plymouth County', '20984f1d-7770-6f6f-dc8d-f65f7b5802dd', datetime.datetime(2022, 2, 2, 12, 24, 33), 1),
#  ('5c611078-5cdf-5631-8ddb-f88bd23e77d7', 'Lucia', 'Cruickshank', datetime.date(1959, 4, 29), 'white', 'Middlesex County', '5c611078-5cdf-5631-8ddb-f88bd23e77d7', datetime.datetime(2022, 1, 20, 5, 34, 32), 1),
#  ('8d4c85ff-0e66-f764-28c6-d5a56cd7ab6c', 'Saran', 'Cronin', datetime.date(2008, 1, 18), 'white', 'Essex County', '8d4c85ff-0e66-f764-28c6-d5a56cd7ab6c', datetime.datetime(2022, 2, 18, 13, 49, 22), 1),
#  ('0c3ec523-c551-7a5c-1d92-a733d9f03339', 'Helena', 'Trantow', datetime.date(1957, 3, 17), 'white', 'Norfolk County', '0c3ec523-c551-7a5c-1d92-a733d9f03339', datetime.datetime(2022, 6, 13, 4, 22, 4), 1),
#  ('ff2dfe68-7dfa-1e80-a5c6-e9a12d2450c3', 'Oneida', 'Gottlieb', datetime.date(1985, 3, 30), 'white', 'Plymouth County', 'ff2dfe68-7dfa-1e80-a5c6-e9a12d2450c3', datetime.datetime(2022, 7, 30, 12, 42, 13), 1),
#  ('904026cd-a3a7-3083-1474-a3101e4d9a1e', 'Alva', 'Ratke', datetime.date(2002, 1, 12), 'black', 'Bristol County', '904026cd-a3a7-3083-1474-a3101e4d9a1e', datetime.datetime(2022, 12, 25, 2, 8, 10), 1),
#  ('4b2f8a02-64dc-3d20-3414-445f5db06ef6', 'Delcie', 'West', datetime.date(1966, 1, 30), 'white', 'Norfolk County', '4b2f8a02-64dc-3d20-3414-445f5db06ef6', datetime.datetime(2022, 4, 4, 7, 57, 35), 1),
#  ('23896bf2-d8b0-c684-8531-a06244df1eab', 'Teresita', 'Stroman', datetime.date(1994, 3, 12), 'black', 'Bristol County', '23896bf2-d8b0-c684-8531-a06244df1eab', datetime.datetime(2022, 5, 21, 22, 32, 50), 1),
#  ('5a7e95ab-0121-3a83-933e-47568038522b', 'Lauri', 'Fritsch', datetime.date(1998, 5, 6), 'white', 'Bristol County', None, None, 0),
#  ('d9f8337d-e58f-0886-3ae8-3efd7e46f4cb', 'Tarsha', 'Runolfsdottir', datetime.date(1995, 5, 12), 'white', 'Barnstable County', None, None, 0),
#  ('b2c83b67-8a60-6ff9-d387-9804216dbe87', 'Princess', 'Hammes', datetime.date(1972, 4, 24), 'white', 'Berkshire County', 'b2c83b67-8a60-6ff9-d387-9804216dbe87', datetime.datetime(2022, 4, 26, 6, 20, 32), 1),
#  ('711826cf-e6d6-eb29-c452-94652378b9f9', 'Latasha', 'Lindgren', datetime.date(1978, 5, 20), 'white', 'Middlesex County', None, None, 0),
#  ('12b65cca-807f-80a2-2fff-78d3f5b3e181', 'Verdie', 'Flatley', datetime.date(1947, 5, 11), 'white', 'Hampden County', '12b65cca-807f-80a2-2fff-78d3f5b3e181', datetime.datetime(2022, 10, 9, 20, 24, 16), 1),
#  ('285e3bf2-6670-915e-a758-27768e36e892', 'Liberty', 'Reichel', datetime.date(2012, 2, 24), 'white', 'Worcester County', '285e3bf2-6670-915e-a758-27768e36e892', datetime.datetime(2022, 3, 4, 21, 27, 25), 1),
#  ('877ac451-5961-580f-f932-398daf51be1c', 'Ana', 'Negrón', datetime.date(2002, 5, 2), 'black', 'Suffolk County', None, None, 0),
#  ('1d8f2c8c-9380-48d3-b876-8d9509d90998', 'Caprice', 'Green', datetime.date(1991, 1, 22), 'white', 'Norfolk County', '1d8f2c8c-9380-48d3-b876-8d9509d90998', datetime.datetime(2022, 5, 31, 23, 48, 9), 1),
#  ('e541ceed-a38c-fbaa-bc12-a78fc758d0fd', 'Nam', 'Hyatt', datetime.date(1979, 2, 10), 'white', 'Worcester County', 'e541ceed-a38c-fbaa-bc12-a78fc758d0fd', datetime.datetime(2022, 8, 28, 3, 46, 51), 1),
#  ('e6479079-321e-260b-45b2-4c21decac2ce', 'Elba', 'Cole', datetime.date(2003, 5, 22), 'white', 'Suffolk County', 'e6479079-321e-260b-45b2-4c21decac2ce', datetime.datetime(2022, 7, 22, 0, 41, 16), 1),
#  ('00a84dca-894a-8626-f852-7a86dfb0b859', 'Toshia', 'Considine', datetime.date(1959, 5, 23), 'asian', 'Norfolk County', '00a84dca-894a-8626-f852-7a86dfb0b859', datetime.datetime(2022, 8, 6, 13, 42, 4), 1),
#  ('ff31edfd-e066-18ee-bb15-1ba9750ada5e', 'Shannon', 'Gerlach', datetime.date(1966, 3, 8), 'white', 'Plymouth County', 'ff31edfd-e066-18ee-bb15-1ba9750ada5e', datetime.datetime(2022, 4, 12, 12, 48), 1),
#  ('5aa558b9-a53d-3661-0c06-03e14c3e0b9f', 'Jeanie', 'Bailey', datetime.date(1966, 4, 3), 'white', 'Middlesex County', '5aa558b9-a53d-3661-0c06-03e14c3e0b9f', datetime.datetime(2022, 5, 8, 21, 23, 12), 1),
#  ('f6ad58a5-d7e3-a351-6c61-7ecef6d193ec', 'Sherrell', 'Jerde', datetime.date(1997, 2, 3), 'black', 'Middlesex County', 'f6ad58a5-d7e3-a351-6c61-7ecef6d193ec', datetime.datetime(2022, 5, 10, 6, 40, 17), 1),
#  ('d8a68778-fb72-875d-31f2-06e2baf7d9bb', 'Lecia', 'Hane', datetime.date(2016, 2, 25), 'white', 'Worcester County', 'd8a68778-fb72-875d-31f2-06e2baf7d9bb', datetime.datetime(2022, 2, 10, 17, 5), 1),
#  ('6caac537-4c2a-64c9-1276-9ba263b65056', 'Elina', 'Kerluke', datetime.date(1977, 1, 7), 'white', 'Norfolk County', '6caac537-4c2a-64c9-1276-9ba263b65056', datetime.datetime(2022, 5, 7, 4, 50, 1), 1),
#  ('2cc92996-cf7e-9586-7c1e-ec0513d63ee7', 'Honey', 'Reynolds', datetime.date(1995, 1, 2), 'white', 'Norfolk County', '2cc92996-cf7e-9586-7c1e-ec0513d63ee7', datetime.datetime(2022, 3, 22, 1, 52, 54), 1),
#  ('4a8204ba-e2e9-16dc-fd1f-f8e856742210', 'Kitty', 'Harber', datetime.date(1949, 2, 13), 'white', 'Essex County', '4a8204ba-e2e9-16dc-fd1f-f8e856742210', datetime.datetime(2022, 6, 27, 7, 34, 43), 1),
#  ('a2f36793-efe9-58f3-cdad-00353c40f1b7', 'Elsy', 'Rippin', datetime.date(2021, 4, 28), 'white', 'Worcester County', 'a2f36793-efe9-58f3-cdad-00353c40f1b7', datetime.datetime(2022, 1, 6, 3, 1, 48), 1),
#  ('5b46fdc3-f459-042c-6b73-b96730f672c8', 'Chung', 'Morar', datetime.date(2008, 1, 20), 'black', 'Middlesex County', '5b46fdc3-f459-042c-6b73-b96730f672c8', datetime.datetime(2022, 2, 21, 4, 5, 59), 1),
#  ('4dd12028-67c5-b6bb-392e-c4f41547abc3', 'Marleen', 'Witting', datetime.date(2016, 5, 28), 'white', 'Worcester County', '4dd12028-67c5-b6bb-392e-c4f41547abc3', datetime.datetime(2022, 5, 14, 15, 43, 46), 1),
#  ('4b47f1dd-ea24-f03a-4aef-f0b0142312ad', 'Leonor', 'Esquivel', datetime.date(1984, 1, 28), 'asian', 'Suffolk County', '4b47f1dd-ea24-f03a-4aef-f0b0142312ad', datetime.datetime(2022, 6, 11, 17, 36, 6), 1),
#  ('bb0c0e05-468e-eee0-a2b2-cf4f556f8303', 'Jenae', 'Wolff', datetime.date(1986, 4, 18), 'white', 'Middlesex County', None, None, 0),
#  ('bb373b27-e0a8-c446-3afe-92b886cdf4e6', 'Robbi', 'Fay', datetime.date(2013, 2, 1), 'white', 'Essex County', 'bb373b27-e0a8-c446-3afe-92b886cdf4e6', datetime.datetime(2022, 2, 5, 0, 59, 8), 1),
#  ('a53c0cbe-8f82-627b-4891-6350a6bf8322', 'Emma', 'Smith', datetime.date(1965, 3, 23), 'white', 'Plymouth County', 'a53c0cbe-8f82-627b-4891-6350a6bf8322', datetime.datetime(2022, 6, 14, 12, 47, 52), 1),
#  ('98d346e0-45ea-6066-64e2-63b76cbec476', 'Serena', 'Bradtke', datetime.date(1969, 5, 16), 'white', 'Essex County', '98d346e0-45ea-6066-64e2-63b76cbec476', datetime.datetime(2022, 12, 9, 22, 8, 42), 1),
#  ('bad6ff27-8229-ca89-fd82-10b8c93cc9bc', 'Darla', 'Rath', datetime.date(1942, 2, 9), 'white', 'Worcester County', 'bad6ff27-8229-ca89-fd82-10b8c93cc9bc', datetime.datetime(2022, 1, 10, 21, 25, 28), 1),
#  ('17cb1ed6-7793-59fc-2bd4-5c6f20d3eef9', 'Christiane', 'Balistreri', datetime.date(1961, 4, 29), 'white', 'Barnstable County', '17cb1ed6-7793-59fc-2bd4-5c6f20d3eef9', datetime.datetime(2022, 7, 3, 3, 44, 27), 1),
#  ('ab394cf5-bed5-5ce6-bcf1-00def0940440', 'Cheri', 'Braun', datetime.date(2008, 4, 17), 'white', 'Franklin County', 'ab394cf5-bed5-5ce6-bcf1-00def0940440', datetime.datetime(2022, 5, 20, 3, 25), 1),
#  ('d46e96da-608f-e1f0-ef69-ccc4c7730acf', 'Deanne', 'Block', datetime.date(1947, 3, 17), 'white', 'Worcester County', 'd46e96da-608f-e1f0-ef69-ccc4c7730acf', datetime.datetime(2022, 2, 22, 1, 32, 40), 1),
#  ('7a1793a1-b8dd-7b64-ffad-f8790ec49d48', 'Frida', 'Bauch', datetime.date(2001, 1, 5), 'black', 'Essex County', None, None, 0),
#  ('7554e9c7-be25-c8b6-5a84-25fd5ea6f996', 'Elvia', 'Botsford', datetime.date(1954, 4, 12), 'white', 'Norfolk County', '7554e9c7-be25-c8b6-5a84-25fd5ea6f996', datetime.datetime(2022, 7, 25, 8, 7, 44), 1),
#  ('a18f1f4e-a0ea-ffd9-bc53-52bcde4323fc', 'Tarra', 'Predovic', datetime.date(1959, 3, 5), 'white', 'Middlesex County', 'a18f1f4e-a0ea-ffd9-bc53-52bcde4323fc', datetime.datetime(2022, 5, 20, 3, 50, 9), 1),
#  ('6bf79a76-daef-a57b-77e0-de3ddb40d496', 'Norine', 'McLaughlin', datetime.date(1943, 1, 2), 'white', 'Plymouth County', '6bf79a76-daef-a57b-77e0-de3ddb40d496', datetime.datetime(2022, 6, 25, 14, 58, 22), 1),
#  ('7c2c7e9d-e8af-93b5-0186-d998959c6025', 'Angelita', 'Schamberger', datetime.date(1946, 5, 27), 'white', 'Middlesex County', '7c2c7e9d-e8af-93b5-0186-d998959c6025', datetime.datetime(2022, 3, 7, 14, 16, 5), 1),
#  ('8d81d10a-e4c8-d742-f108-de20dbb19832', 'Dinorah', 'MacGyver', datetime.date(2007, 4, 24), 'white', 'Plymouth County', '8d81d10a-e4c8-d742-f108-de20dbb19832', datetime.datetime(2022, 6, 1, 1, 16, 36), 1),
#  ('f6ab4d57-498d-c2a2-d877-8df908631238', 'Stephani', 'Mayert', datetime.date(1943, 4, 1), 'white', 'Norfolk County', 'f6ab4d57-498d-c2a2-d877-8df908631238', datetime.datetime(2022, 9, 15, 13, 4, 55), 1),
#  ('241a65a5-4630-64a8-eefa-a72bdf0bf5fc', 'Loreen', 'Moore', datetime.date(1970, 3, 8), 'black', 'Middlesex County', '241a65a5-4630-64a8-eefa-a72bdf0bf5fc', datetime.datetime(2022, 9, 19, 1, 3, 48), 1),
#  ('de6ad1ff-95ac-f276-b4ec-3f5c6f2851a5', 'Keshia', 'Kutch', datetime.date(1971, 5, 28), 'white', 'Middlesex County', 'de6ad1ff-95ac-f276-b4ec-3f5c6f2851a5', datetime.datetime(2022, 7, 29, 9, 46, 25), 1),
#  ('d3402c43-7794-385f-c47d-b947cfefe683', 'Mayte', 'Flores', datetime.date(1991, 3, 4), 'asian', 'Middlesex County', 'd3402c43-7794-385f-c47d-b947cfefe683', datetime.datetime(2022, 5, 16, 21, 36, 16), 1),
#  ('3f745400-5ef1-9038-2dd3-48298abddeb1', 'Valencia', 'Johnston', datetime.date(1976, 2, 16), 'white', 'Middlesex County', '3f745400-5ef1-9038-2dd3-48298abddeb1', datetime.datetime(2022, 6, 13, 12, 42, 31), 1),
#  ('b5aa763a-054e-355e-f5fd-f42190f3936f', 'Tony', 'Lesch', datetime.date(2005, 5, 6), 'white', 'Middlesex County', None, None, 0),
#  ('fb13d226-6bf2-8dbf-9436-fabb6a226d88', 'Alishia', 'Bradtke', datetime.date(1975, 2, 26), 'white', 'Berkshire County', None, None, 0),
#  ('3bb6322f-4eb3-1bf2-7e29-4a67a3268a45', 'Gladis', 'Gaylord', datetime.date(1955, 1, 9), 'white', 'Bristol County', '3bb6322f-4eb3-1bf2-7e29-4a67a3268a45', datetime.datetime(2022, 10, 30, 11, 0, 51), 1),
#  ('d93dd637-3f41-9499-87ac-dc4291cad4be', 'Erlene', 'Rogahn', datetime.date(1948, 3, 14), 'white', 'Barnstable County', 'd93dd637-3f41-9499-87ac-dc4291cad4be', datetime.datetime(2022, 1, 2, 22, 27, 11), 1),
#  ('7ebb716c-011a-9a50-93da-a55f7fd9a602', 'Latanya', 'Renner', datetime.date(1959, 3, 7), 'black', 'Essex County', '7ebb716c-011a-9a50-93da-a55f7fd9a602', datetime.datetime(2022, 11, 5, 23, 10, 17), 1),
#  ('244b7b9a-3845-b4d2-1b6b-5212e8266721', 'Rosenda', 'Miller', datetime.date(1961, 5, 27), 'white', 'Bristol County', '244b7b9a-3845-b4d2-1b6b-5212e8266721', datetime.datetime(2022, 7, 31, 4, 30, 35), 1),
#  ('81016fcf-5460-1d0b-f816-f601c16ff0fa', 'Hollie', 'Kozey', datetime.date(1963, 1, 8), 'white', 'Norfolk County', '81016fcf-5460-1d0b-f816-f601c16ff0fa', datetime.datetime(2022, 4, 5, 22, 59, 29), 1),
#  ('ed7244ec-29f3-d5a8-0e86-bcf6e07c6309', 'Marcell', 'Stiedemann', datetime.date(1981, 5, 2), 'white', 'Worcester County', 'ed7244ec-29f3-d5a8-0e86-bcf6e07c6309', datetime.datetime(2022, 5, 15, 2, 55, 44), 1),
#  ('1848caec-f36e-c253-cd47-1c062579de24', 'Shawnna', 'Will', datetime.date(1947, 2, 21), 'white', 'Middlesex County', '1848caec-f36e-c253-cd47-1c062579de24', datetime.datetime(2022, 2, 12, 6, 59, 4), 1),
#  ('f6e13cf6-887f-417d-e764-4591999f9f6f', 'Katherin', 'Jenkins', datetime.date(1987, 2, 19), 'white', 'Essex County', None, None, 0),
#  ('00ecc35c-a9e2-b843-4da4-ba2b5985beb4', 'Yevette', 'Cartwright', datetime.date(2009, 4, 2), 'white', 'Suffolk County', '00ecc35c-a9e2-b843-4da4-ba2b5985beb4', datetime.datetime(2022, 4, 28, 20, 51, 9), 1),
#  ('f74ecb5b-2318-dbd1-f569-42cddb466661', 'Tatiana', 'Kuhic', datetime.date(1982, 2, 14), 'white', 'Essex County', 'f74ecb5b-2318-dbd1-f569-42cddb466661', datetime.datetime(2022, 2, 20, 11, 31, 54), 1),
#  ('5baa38c5-4965-b7ff-ee21-3a003cccfdb0', 'Samira', 'Volkman', datetime.date(1978, 3, 14), 'white', 'Middlesex County', '5baa38c5-4965-b7ff-ee21-3a003cccfdb0', datetime.datetime(2022, 3, 29, 15, 16, 3), 1),
#  ('98fa812b-cc09-b114-7766-b0a41801a01f', 'Ela', 'Ratke', datetime.date(2021, 3, 17), 'white', 'Middlesex County', None, None, 0),
#  ('70d19f16-c18b-4be2-c44a-14cb76751bd2', 'Phyliss', 'Schoen', datetime.date(2021, 5, 26), 'white', 'Middlesex County', '70d19f16-c18b-4be2-c44a-14cb76751bd2', datetime.datetime(2022, 2, 2, 7, 26, 10), 1),
#  ('95758a9a-8007-9b43-2828-3ad0cfa773cc', 'Lilia', 'Runolfsson', datetime.date(1957, 3, 4), 'white', 'Berkshire County', '95758a9a-8007-9b43-2828-3ad0cfa773cc', datetime.datetime(2022, 5, 31, 3, 5, 7), 1),
#  ('60338e93-731f-ee90-b888-e8d8a7406e9f', 'Sandi', 'Kessler', datetime.date(2008, 1, 13), 'white', 'Middlesex County', '60338e93-731f-ee90-b888-e8d8a7406e9f', datetime.datetime(2022, 2, 14, 2, 32), 1),
#  ('d6558e6d-1c4a-3daa-6e80-be6becf91d57', 'Jacquie', 'Hoppe', datetime.date(1996, 5, 26), 'white', 'Hampden County', 'd6558e6d-1c4a-3daa-6e80-be6becf91d57', datetime.datetime(2022, 9, 5, 1, 15, 4), 1),
#  ('0c5a06ce-905f-8dcc-e9d7-3100be55fcf1', 'Aleen', 'Wilkinson', datetime.date(1976, 3, 24), 'white', 'Essex County', '0c5a06ce-905f-8dcc-e9d7-3100be55fcf1', datetime.datetime(2022, 2, 9, 16, 50, 39), 1),
#  ('f63aba91-328f-98d1-1d8f-128ad7845ca7', 'Freddie', 'Grady', datetime.date(1963, 5, 22), 'white', 'Worcester County', 'f63aba91-328f-98d1-1d8f-128ad7845ca7', datetime.datetime(2022, 12, 14, 9, 26, 19), 1),
#  ('e87c9ebc-3ffd-0f08-41e5-a4c956b1a5dc', 'Ocie', 'Hills', datetime.date(1957, 3, 30), 'white', 'Essex County', None, None, 0),
#  ('2fa588ce-db55-e944-8138-a095a3a5db65', 'Kiera', 'Kilback', datetime.date(1956, 2, 23), 'asian', 'Norfolk County', '2fa588ce-db55-e944-8138-a095a3a5db65', datetime.datetime(2022, 12, 23, 4, 42, 34), 1),
#  ('664c647f-c908-450a-493a-0eb30f31eb54', 'Barbara', 'Schuppe', datetime.date(1985, 5, 15), 'white', 'Bristol County', '664c647f-c908-450a-493a-0eb30f31eb54', datetime.datetime(2022, 8, 4, 0, 17, 33), 1),
#  ('9b2c63fe-25dc-5428-936d-03686ae01840', 'Ira', 'Hermiston', datetime.date(2011, 1, 13), 'white', 'Worcester County', '9b2c63fe-25dc-5428-936d-03686ae01840', datetime.datetime(2022, 1, 27, 9, 5, 30), 1),
#  ('b83059e8-0c74-1eba-875a-2a4914da4ced', 'Joshua', 'Funk', datetime.date(1982, 5, 7), 'white', 'Worcester County', 'b83059e8-0c74-1eba-875a-2a4914da4ced', datetime.datetime(2022, 8, 5, 16, 8, 31), 1),
#  ('dec7fb57-0a1b-9b36-65e5-24f90df7a28b', 'Faviola', 'Olson', datetime.date(1931, 4, 10), 'white', 'Plymouth County', 'dec7fb57-0a1b-9b36-65e5-24f90df7a28b', datetime.datetime(2022, 12, 3, 6, 40, 39), 1),
#  ('a0cec8c9-61d4-77d4-6d7d-408652490192', 'Amy', 'Hand', datetime.date(1969, 5, 14), 'white', 'Hampden County', 'a0cec8c9-61d4-77d4-6d7d-408652490192', datetime.datetime(2022, 6, 1, 21, 58, 3), 1),
#  ('9b0a78b9-e4b5-2529-d02d-f666f0b15217', 'Rosella', 'Frami', datetime.date(1983, 2, 19), 'white', 'Norfolk County', None, None, 0),
#  ('7367c767-4a24-3d1c-2e5a-4f476f645402', 'Dannette', 'Ebert', datetime.date(2006, 3, 21), 'white', 'Essex County', '7367c767-4a24-3d1c-2e5a-4f476f645402', datetime.datetime(2022, 5, 3, 8, 17, 16), 1),
#  ('f5bd5993-b529-4c1a-7b0c-5ed72676e652', 'Georgeann', 'Daniel', datetime.date(1960, 1, 16), 'asian', 'Essex County', 'f5bd5993-b529-4c1a-7b0c-5ed72676e652', datetime.datetime(2022, 3, 27, 6, 2, 9), 1),
#  ('5197f54f-e52f-1644-c08a-8913ff758491', 'Alycia', 'Nienow', datetime.date(2000, 1, 3), 'white', 'Norfolk County', '5197f54f-e52f-1644-c08a-8913ff758491', datetime.datetime(2022, 10, 11, 3, 50, 57), 1),
#  ('8efe97c0-3642-05aa-693d-3832fd31f3d8', 'Caron', 'Weber', datetime.date(1989, 5, 25), 'white', 'Norfolk County', '8efe97c0-3642-05aa-693d-3832fd31f3d8', datetime.datetime(2022, 4, 1, 4, 46, 10), 1),
#  ('555304cc-6c1f-93b1-f755-fa4188421a11', 'Amal', 'Aufderhar', datetime.date(1955, 1, 19), 'white', 'Middlesex County', '555304cc-6c1f-93b1-f755-fa4188421a11', datetime.datetime(2022, 4, 27, 11, 41, 10), 1),
#  ('d4c4fc44-4d77-9832-d6bf-26d9b5ec345e', 'Babara', 'Hayes', datetime.date(1956, 2, 19), 'white', 'Worcester County', 'd4c4fc44-4d77-9832-d6bf-26d9b5ec345e', datetime.datetime(2022, 8, 21, 16, 14, 1), 1),
#  ('1185fb6e-2d90-53e6-24c4-2ea80a489933', 'Lucilla', 'Simonis', datetime.date(1962, 2, 5), 'white', 'Middlesex County', '1185fb6e-2d90-53e6-24c4-2ea80a489933', datetime.datetime(2022, 9, 6, 2, 35, 51), 1),
#  ('21a9e140-67c9-69fa-19fd-4bb2de1b4246', 'Kimberlee', 'Hegmann', datetime.date(1993, 1, 31), 'black', 'Norfolk County', '21a9e140-67c9-69fa-19fd-4bb2de1b4246', datetime.datetime(2022, 10, 30, 13, 21, 9), 1),
#  ('e4e5598f-2f8f-4b8c-7724-ece22a68fa65', 'Stephine', 'Ziemann', datetime.date(2005, 4, 3), 'white', 'Norfolk County', 'e4e5598f-2f8f-4b8c-7724-ece22a68fa65', datetime.datetime(2022, 5, 22, 20, 22, 40), 1),
#  ('8809d25a-4f07-5c52-1644-e7f82e9ffb0f', 'Sharan', 'Thompson', datetime.date(1965, 1, 10), 'white', 'Nantucket County', '8809d25a-4f07-5c52-1644-e7f82e9ffb0f', datetime.datetime(2022, 4, 10, 8, 3), 1),
#  ('950024e6-d878-9b17-9dab-d3810a617eb0', 'Ileen', 'Dickens', datetime.date(1960, 5, 21), 'white', 'Worcester County', '950024e6-d878-9b17-9dab-d3810a617eb0', datetime.datetime(2022, 7, 30, 8, 18, 53), 1),
#  ('e357a442-c0e3-b394-7efe-b024a61e7ea6', 'Barbara', 'Saiz', datetime.date(2004, 3, 24), 'white', 'Worcester County', 'e357a442-c0e3-b394-7efe-b024a61e7ea6', datetime.datetime(2022, 5, 25, 13, 58, 20), 1),
#  ('4b20bea8-3aab-0c0e-09c5-66115836a90c', 'Williemae', 'Padberg', datetime.date(1968, 3, 20), 'white', 'Plymouth County', '4b20bea8-3aab-0c0e-09c5-66115836a90c', datetime.datetime(2022, 4, 13, 11, 36, 41), 1),
#  ('97252b77-a5dd-8433-3403-37de2fcb184b', 'Dacia', 'Corkery', datetime.date(1957, 5, 5), 'white', 'Barnstable County', '97252b77-a5dd-8433-3403-37de2fcb184b', datetime.datetime(2022, 3, 20, 11, 3, 6), 1),
#  ('4bf021ca-1ba6-86fe-3f28-664238d714e4', 'Natalia', 'Ceballos', datetime.date(1989, 5, 4), 'white', 'Norfolk County', None, None, 0),
#  ('853b45ce-1618-9add-8d9f-4bcb043a74b5', 'Bennie', 'Howe', datetime.date(2006, 3, 20), 'asian', 'Middlesex County', '853b45ce-1618-9add-8d9f-4bcb043a74b5', datetime.datetime(2022, 5, 3, 5, 52), 1),
#  ('5fc1f05b-07e8-6ab9-44f9-8366ed8afe97', 'Monet', 'Kassulke', datetime.date(1979, 4, 21), 'white', 'Hampden County', None, None, 0),
#  ('a70835cf-556c-26f1-303d-42c46ab788f0', 'Venetta', 'Wolf', datetime.date(2000, 3, 9), 'white', 'Middlesex County', 'a70835cf-556c-26f1-303d-42c46ab788f0', datetime.datetime(2022, 5, 12, 8, 41, 43), 1),
#  ('019bca57-f817-dc43-812e-ea582b553927', 'Kiley', 'Block', datetime.date(1982, 3, 13), 'white', 'Worcester County', '019bca57-f817-dc43-812e-ea582b553927', datetime.datetime(2022, 3, 19, 14, 36, 41), 1),
#  ('c05bdc70-efc0-3391-c4de-2d81becd07f0', 'Marvis', 'Yost', datetime.date(1965, 3, 6), 'white', 'Middlesex County', 'c05bdc70-efc0-3391-c4de-2d81becd07f0', datetime.datetime(2022, 5, 22, 6, 21, 9), 1),
#  ('b1202621-e462-aae5-b4de-94e85a6a6851', 'Alvera', 'Harvey', datetime.date(1953, 2, 5), 'white', 'Essex County', 'b1202621-e462-aae5-b4de-94e85a6a6851', datetime.datetime(2022, 9, 29, 19, 34, 53), 1),
#  ('6af32616-d2b3-1bdc-55ff-d04d6f1b49f7', 'Hermina', 'Conn', datetime.date(1971, 5, 18), 'white', 'Plymouth County', '6af32616-d2b3-1bdc-55ff-d04d6f1b49f7', datetime.datetime(2022, 5, 24, 21, 10, 29), 1),
#  ('0194e91f-8b74-4556-8cf4-ea7ecbe87de7', 'Albertina', 'Herzog', datetime.date(1990, 5, 13), 'white', 'Norfolk County', None, None, 0),
#  ('58557d8c-16f1-3992-db1b-f1cddaf570e4', 'Karan', 'Wolf', datetime.date(2008, 1, 22), 'white', 'Barnstable County', '58557d8c-16f1-3992-db1b-f1cddaf570e4', datetime.datetime(2022, 2, 22, 16, 48, 48), 1),
#  ('af9c070e-f102-0aaf-a5aa-d9383202abb8', 'Marty', 'Zieme', datetime.date(1958, 4, 8), 'white', 'Essex County', 'af9c070e-f102-0aaf-a5aa-d9383202abb8', datetime.datetime(2022, 8, 23, 22, 10, 10), 1),
#  ('3f637ece-9b1b-9739-4bd8-9be6c14eecfd', 'Vivien', 'Stroman', datetime.date(1962, 3, 28), 'white', 'Barnstable County', '3f637ece-9b1b-9739-4bd8-9be6c14eecfd', datetime.datetime(2022, 5, 25, 19, 37, 38), 1),
#  ('1794996b-8d32-8061-2fb1-e99d1e2a5990', 'Charlotte', 'Walsh', datetime.date(2003, 3, 18), 'white', 'Middlesex County', '1794996b-8d32-8061-2fb1-e99d1e2a5990', datetime.datetime(2022, 5, 18, 0, 4, 40), 1),
#  ('e372180e-e09a-1498-ac99-34f61b1c371d', 'Teofila', 'Stoltenberg', datetime.date(1975, 5, 13), 'white', 'Norfolk County', 'e372180e-e09a-1498-ac99-34f61b1c371d', datetime.datetime(2022, 9, 27, 10, 32, 54), 1),
#  ('0b2bdd86-87b5-9f66-3b12-69d96fb140e7', 'Jacquelyn', 'Monahan', datetime.date(2020, 3, 19), 'black', 'Plymouth County', '0b2bdd86-87b5-9f66-3b12-69d96fb140e7', datetime.datetime(2022, 2, 25, 1, 19, 53), 1),
#  ('4421d444-93ec-b0d3-4008-8975538c0c76', 'Danika', 'Yundt', datetime.date(1993, 2, 25), 'asian', 'Middlesex County', None, None, 0),
#  ('81880318-5972-38c4-b449-11c2e53183e7', 'Connie', 'Emmerich', datetime.date(1958, 4, 24), 'white', 'Barnstable County', '81880318-5972-38c4-b449-11c2e53183e7', datetime.datetime(2022, 2, 10, 9, 0, 19), 1),
#  ('29773ce0-818f-5efe-fb46-91494af0257b', 'Leanna', 'Haley', datetime.date(2015, 2, 3), 'black', 'Middlesex County', '29773ce0-818f-5efe-fb46-91494af0257b', datetime.datetime(2022, 1, 26, 4, 21, 52), 1),
#  ('79fc728c-4fb8-493a-9c55-52b523a5e9dd', 'Elodia', 'Lockman', datetime.date(1968, 2, 8), 'white', 'Bristol County', '79fc728c-4fb8-493a-9c55-52b523a5e9dd', datetime.datetime(2022, 3, 3, 15, 51, 31), 1),
#  ('35ec9baa-6d52-b930-e672-3d6edfd02541', 'Isabela', 'Villa', datetime.date(1985, 1, 10), 'white', 'Middlesex County', '35ec9baa-6d52-b930-e672-3d6edfd02541', datetime.datetime(2022, 10, 6, 8, 52, 16), 1),
#  ('e13654fa-a40d-2466-0f1d-2538bd47e254', 'Penelope', 'Watsica', datetime.date(1996, 4, 1), 'white', 'Worcester County', None, None, 0),
#  ('453b691b-e13b-2f80-e8c0-d520bbc1b9ce', 'Candra', 'Bernhard', datetime.date(1960, 5, 30), 'black', 'Worcester County', '453b691b-e13b-2f80-e8c0-d520bbc1b9ce', datetime.datetime(2022, 8, 8, 8, 55, 52), 1),
#  ('d1651a80-0227-9612-b570-b51057b2e8bc', 'Cristi', 'Feil', datetime.date(1976, 3, 15), 'white', 'Worcester County', 'd1651a80-0227-9612-b570-b51057b2e8bc', datetime.datetime(2022, 4, 5, 6, 15, 26), 1),
#  ('88101e9f-4ab4-971d-d860-6b8ab00b9ee7', 'Jalisa', 'Kohler', datetime.date(1998, 5, 14), 'white', 'Dukes County', None, None, 0),
#  ('6136477c-d340-0901-de72-689052d432c2', 'Meryl', 'Goodwin', datetime.date(1995, 5, 29), 'white', 'Hampden County', '6136477c-d340-0901-de72-689052d432c2', datetime.datetime(2022, 9, 12, 16, 51, 1), 1),
#  ('be793f0b-f62f-2c7c-54e9-feb075070572', 'Latina', 'Carter', datetime.date(1948, 4, 28), 'asian', 'Norfolk County', 'be793f0b-f62f-2c7c-54e9-feb075070572', datetime.datetime(2022, 3, 24, 3, 25, 49), 1),
#  ('a911da81-f85f-8972-23b3-bc3dcbda89af', 'Laree', 'Rogahn', datetime.date(1974, 5, 9), 'white', 'Bristol County', 'a911da81-f85f-8972-23b3-bc3dcbda89af', datetime.datetime(2022, 10, 13, 17, 9, 17), 1),
#  ('377b3fb1-64bb-b1fb-8b8f-f7e675ab6573', 'Almeda', 'Kovacek', datetime.date(1958, 2, 13), 'white', 'Middlesex County', '377b3fb1-64bb-b1fb-8b8f-f7e675ab6573', datetime.datetime(2022, 12, 30, 3, 40, 35), 1),
#  ('5d0974d3-7fb4-fb7d-5ded-6d5acab34157', 'Joann', 'Gleichner', datetime.date(1981, 4, 15), 'black', 'Worcester County', None, None, 0),
#  ('4c394304-9b80-18d7-e103-dd82c526a754', 'Concetta', 'Zemlak', datetime.date(1983, 4, 18), 'white', 'Worcester County', None, None, 0),
#  ('a687f660-eca0-6fd0-7f45-abc06c86024e', 'Darcey', 'Gleichner', datetime.date(1969, 1, 3), 'asian', 'Norfolk County', 'a687f660-eca0-6fd0-7f45-abc06c86024e', datetime.datetime(2022, 7, 8, 12, 10, 44), 1),
#  ('ca62e079-6ad1-ad17-fc5d-6d97ba2d7269', 'Lennie', 'Grant', datetime.date(1956, 2, 14), 'white', 'Worcester County', 'ca62e079-6ad1-ad17-fc5d-6d97ba2d7269', datetime.datetime(2022, 5, 4, 3, 53, 42), 1),
#  ('5f77688e-b67d-b9df-7a4c-f6016c914198', 'Devona', 'Wiza', datetime.date(1944, 1, 8), 'white', 'Bristol County', '5f77688e-b67d-b9df-7a4c-f6016c914198', datetime.datetime(2022, 12, 3, 15, 29), 1),
#  ('31d15a8d-4290-34e0-12ac-ba1831a5e09e', 'Glady', 'Eichmann', datetime.date(1968, 1, 30), 'white', 'Middlesex County', '31d15a8d-4290-34e0-12ac-ba1831a5e09e', datetime.datetime(2022, 2, 23, 5, 44, 23), 1),
#  ('0e09d81e-f210-12d2-63d0-a51246fe9668', 'Kimberlee', 'McCullough', datetime.date(1968, 5, 30), 'white', 'Essex County', '0e09d81e-f210-12d2-63d0-a51246fe9668', datetime.datetime(2022, 6, 23, 12, 18, 1), 1),
#  ('7306efad-789c-c2d6-10fe-73d6f5add6c0', 'Carlena', 'Monahan', datetime.date(1992, 4, 3), 'white', 'Worcester County', None, None, 0),
#  ('1c48b61a-4f10-42e7-4638-1ce2387476c6', 'Renna', 'Stark', datetime.date(1977, 3, 20), 'white', 'Middlesex County', None, None, 0),
#  ('b05c346a-3c70-228f-0094-030275462216', 'Analisa', 'Kuvalis', datetime.date(2007, 4, 3), 'white', 'Worcester County', 'b05c346a-3c70-228f-0094-030275462216', datetime.datetime(2022, 5, 10, 12, 55, 5), 1),
#  ('fd398384-7c5a-39a5-a43e-17d2dfda9690', 'Vivien', 'Witting', datetime.date(1971, 4, 21), 'asian', 'Worcester County', 'fd398384-7c5a-39a5-a43e-17d2dfda9690', datetime.datetime(2022, 10, 20, 0, 30, 16), 1),
#  ('31545fde-c959-bca1-558a-7b433f271e24', 'Raguel', 'Gerlach', datetime.date(1950, 5, 29), 'asian', 'Plymouth County', '31545fde-c959-bca1-558a-7b433f271e24', datetime.datetime(2022, 10, 4, 5, 31, 37), 1),
#  ('ff198de8-2bbb-d456-5faf-b6059ec83bec', 'Norma', 'Ferrer', datetime.date(1966, 4, 29), 'black', 'Worcester County', 'ff198de8-2bbb-d456-5faf-b6059ec83bec', datetime.datetime(2022, 11, 11, 18, 29, 43), 1),
#  ('66033b3d-d3b6-6f73-d3df-31ed0e04d96b', 'Odilia', 'Parisian', datetime.date(1972, 4, 8), 'black', 'Worcester County', '66033b3d-d3b6-6f73-d3df-31ed0e04d96b', datetime.datetime(2022, 5, 15, 6, 20, 54), 1),
#  ('7780d76b-4a01-7011-0a82-2991af6cd2db', 'Anneliese', 'Jacobson', datetime.date(1980, 4, 12), 'white', 'Worcester County', '7780d76b-4a01-7011-0a82-2991af6cd2db', datetime.datetime(2022, 4, 23, 19, 16, 35), 1),
#  ('4d9fccf3-a921-aeb3-196e-927e10ae9db7', 'Rena', 'Frami', datetime.date(1980, 1, 29), 'white', 'Middlesex County', '4d9fccf3-a921-aeb3-196e-927e10ae9db7', datetime.datetime(2022, 2, 8, 13, 30, 57), 1),
#  ('ca0e0bb6-c3bd-52b4-d7a4-bd4ca92aaab9', 'Mammie', 'Will', datetime.date(1997, 4, 5), 'white', 'Barnstable County', 'ca0e0bb6-c3bd-52b4-d7a4-bd4ca92aaab9', datetime.datetime(2022, 6, 11, 11, 5, 43), 1),
#  ('11cc1b56-6ad5-8b89-1b12-12627c7c9a82', 'Willia', 'Johns', datetime.date(1981, 4, 5), 'white', 'Middlesex County', None, None, 0),
#  ('b88721b6-9269-1e3c-e3e8-4f9718cacc39', 'Lavonda', 'Reynolds', datetime.date(2009, 2, 13), 'white', 'Essex County', None, None, 0),
#  ('37f937f5-1362-8b86-8ada-12407ae3ab34', 'Ilana', 'Kutch', datetime.date(2001, 2, 1), 'white', 'Middlesex County', None, None, 0),
# ...
#  ('85a91589-7c42-e9bc-b262-817ed39036f5', 'Dorothea', 'Goyette', datetime.date(1999, 3, 7), 'white', 'Middlesex County', None, None, 0),
#  ('0eced16f-d2a8-076a-fbe3-d061ae73d270', 'Nichelle', 'Schumm', datetime.date(1970, 1, 3), 'white', 'Bristol County', '0eced16f-d2a8-076a-fbe3-d061ae73d270', datetime.datetime(2022, 1, 15, 16, 46, 46), 1),
#  ('20928c03-4485-e209-67fe-91d5f664d3ab', 'Maryjo', 'Little', datetime.date(2018, 2, 17), 'white', 'Essex County', '20928c03-4485-e209-67fe-91d5f664d3ab', datetime.datetime(2022, 1, 22, 12, 55, 52), 1),
#  ('5d0a2333-6907-7eb7-9107-6c5de4b73700', 'Katherine', 'Lebsack', datetime.date(1972, 3, 8), 'white', 'Middlesex County', '5d0a2333-6907-7eb7-9107-6c5de4b73700', datetime.datetime(2022, 9, 7, 23, 46, 10), 1),
#  ('496cd9b0-141b-087b-a5f9-f97f28abe917', 'Cecila', 'Toy', datetime.date(2011, 4, 15), 'white', 'Hampden County', '496cd9b0-141b-087b-a5f9-f97f28abe917', datetime.datetime(2022, 4, 29, 12, 23, 50), 1),
#  ('de69b6b2-3ea3-64fe-c2b7-3585f8919d3e', 'Camila', 'Predovic', datetime.date(2019, 4, 2), 'white', 'Middlesex County', 'de69b6b2-3ea3-64fe-c2b7-3585f8919d3e', datetime.datetime(2022, 3, 9, 0, 57, 4), 1),
#  ('f8a2bc9a-f281-5648-e112-d5d22ca9da32', 'Sherri', 'Lakin', datetime.date(2001, 3, 24), 'white', 'Middlesex County', None, None, 0),
#  ('545939c4-1531-000d-a661-5f408772b0fb', 'Lurlene', 'West', datetime.date(2010, 4, 10), 'white', 'Plymouth County', '545939c4-1531-000d-a661-5f408772b0fb', datetime.datetime(2022, 5, 1, 0, 12, 16), 1),
#  ('39bd8885-5ac6-8e88-8cf1-84997dc80da5', 'Carole', 'Tremblay', datetime.date(1978, 5, 29), 'white', 'Plymouth County', '39bd8885-5ac6-8e88-8cf1-84997dc80da5', datetime.datetime(2022, 6, 13, 23, 13, 40), 1),
#  ('df9f8955-d324-e2b1-97ff-993ae8dcff1c', 'Antonette', 'Swift', datetime.date(2018, 4, 13), 'white', 'Suffolk County', 'df9f8955-d324-e2b1-97ff-993ae8dcff1c', datetime.datetime(2022, 3, 18, 23, 46, 29), 1),
#  ('ebc179f0-1bca-ecc6-55f4-72e91ae0e542', 'Kelsi', 'Gusikowski', datetime.date(2012, 2, 3), 'white', 'Norfolk County', 'ebc179f0-1bca-ecc6-55f4-72e91ae0e542', datetime.datetime(2022, 11, 12, 7, 19, 8), 1),
#  ('5a0a2015-cbe6-a431-8b51-b9b2a2c16ce7', 'Lorie', 'Hintz', datetime.date(1974, 3, 3), 'white', 'Worcester County', '5a0a2015-cbe6-a431-8b51-b9b2a2c16ce7', datetime.datetime(2022, 3, 27, 15, 11, 22), 1),
#  ('4214bd4d-1203-96ea-ca6b-6de0de951d8f', 'Eula', 'Beier', datetime.date(1979, 3, 10), 'white', 'Essex County', None, None, 0),
#  ('b2f65a11-3ba3-ab90-a5fe-b312e9bd0cb8', 'Edythe', 'Mertz', datetime.date(1954, 3, 1), 'white', 'Bristol County', 'b2f65a11-3ba3-ab90-a5fe-b312e9bd0cb8', datetime.datetime(2022, 1, 31, 11, 19, 24), 1),
#  ('13eae0a5-69d8-b254-c884-eb4c21f71659', 'Janine', 'Thiel', datetime.date(1941, 1, 6), 'white', 'Plymouth County', '13eae0a5-69d8-b254-c884-eb4c21f71659', datetime.datetime(2022, 7, 25, 18, 11, 12), 1),
#  ('92b5c193-7d9b-0dc0-259c-bd551cc0dc8d', 'Ulrike', 'Spencer', datetime.date(2007, 5, 13), 'hawaiian', 'Essex County', '92b5c193-7d9b-0dc0-259c-bd551cc0dc8d', datetime.datetime(2022, 6, 19, 18, 57, 23), 1),
#  ('97575ee4-6663-f9f5-ffb1-24032e9fe9db', 'Elyse', 'Kautzer', datetime.date(2010, 3, 12), 'white', 'Worcester County', '97575ee4-6663-f9f5-ffb1-24032e9fe9db', datetime.datetime(2022, 4, 1, 23, 32, 11), 1),
#  ('b58f76b7-e51b-f708-80d0-747cee97ae63', 'Cleotilde', 'Quitzon', datetime.date(1965, 4, 22), 'white', 'Norfolk County', 'b58f76b7-e51b-f708-80d0-747cee97ae63', datetime.datetime(2022, 6, 2, 20, 18, 17), 1),
#  ('0c8bbd82-3a19-eb74-08c2-39383066f701', 'Melony', 'Smith', datetime.date(1999, 2, 18), 'white', 'Plymouth County', '0c8bbd82-3a19-eb74-08c2-39383066f701', datetime.datetime(2022, 5, 12, 18, 11, 12), 1),
#  ('4d505615-7743-da3c-17c2-5807efbdda84', 'Hertha', 'Collier', datetime.date(1989, 5, 24), 'white', 'Bristol County', None, None, 0),
#  ('feace96a-2a9e-ec8e-35f4-2b527851bda7', 'Amira', 'Schinner', datetime.date(2017, 1, 3), 'white', 'Barnstable County', 'feace96a-2a9e-ec8e-35f4-2b527851bda7', datetime.datetime(2022, 12, 20, 19, 18, 4), 1),
#  ('dba10e42-4fe7-f046-9c68-126693b8a4b6', 'Colette', 'Ernser', datetime.date(1993, 2, 28), 'white', 'Hampden County', 'dba10e42-4fe7-f046-9c68-126693b8a4b6', datetime.datetime(2022, 4, 3, 13, 22, 10), 1),
#  ('8f20ecd1-6a9d-35ae-ff59-055f04f81f1c', 'Bettie', 'Watsica', datetime.date(2013, 2, 28), 'white', 'Essex County', '8f20ecd1-6a9d-35ae-ff59-055f04f81f1c', datetime.datetime(2022, 3, 4, 7, 40, 13), 1),
#  ('c47cd97a-846a-405f-7f55-9a31e5d0c198', 'Katie', 'Becker', datetime.date(1988, 4, 4), 'white', 'Plymouth County', 'c47cd97a-846a-405f-7f55-9a31e5d0c198', datetime.datetime(2022, 6, 20, 14, 47, 30), 1),
#  ('96ddaaa9-bbb1-82ae-e989-ba2568c8bda3', 'Asha', 'Watsica', datetime.date(1960, 5, 11), 'asian', 'Middlesex County', '96ddaaa9-bbb1-82ae-e989-ba2568c8bda3', datetime.datetime(2022, 7, 20, 15, 23, 52), 1),
#  ('132cc2c9-6d18-49b8-1255-b20af87afc49', 'Raisa', 'Johnson', datetime.date(1986, 3, 10), 'black', 'Suffolk County', None, None, 0),
#  ('a76455a9-a4f2-f352-f8a0-37e025d7cc01', 'Ramona', 'Santillán', datetime.date(2016, 1, 19), 'asian', 'Worcester County', 'a76455a9-a4f2-f352-f8a0-37e025d7cc01', datetime.datetime(2022, 1, 5, 3, 43, 51), 1),
#  ('e26fa18a-0b2f-87a6-2a01-9b27363dd8e5', 'Anglea', 'Durgan', datetime.date(1998, 1, 3), 'white', 'Essex County', 'e26fa18a-0b2f-87a6-2a01-9b27363dd8e5', datetime.datetime(2022, 4, 3, 7, 35, 59), 1),
#  ('a5d1b165-a43a-c551-b3ab-c6e7b5a3c7b1', 'Roselia', 'Keebler', datetime.date(2021, 4, 17), 'white', 'Essex County', None, None, 0),
#  ('2b00f742-f0b7-5870-3b76-9864f77ade4e', 'Katia', 'Nitzsche', datetime.date(1996, 3, 7), 'white', 'Middlesex County', '2b00f742-f0b7-5870-3b76-9864f77ade4e', datetime.datetime(2022, 1, 28, 6, 38, 20), 1),
#  ('3b5af0f4-e05a-764d-037b-2af2fb13a9f0', 'Chantal', 'Conroy', datetime.date(1977, 2, 12), 'white', 'Bristol County', '3b5af0f4-e05a-764d-037b-2af2fb13a9f0', datetime.datetime(2022, 9, 10, 12, 43, 54), 1),
#  ('fdc1701f-587b-6247-eada-f7ba5be24268', 'Janiece', 'Lynch', datetime.date(1967, 3, 25), 'white', 'Hampshire County', 'fdc1701f-587b-6247-eada-f7ba5be24268', datetime.datetime(2022, 12, 24, 18, 55, 20), 1),
#  ('582ea3e4-3b76-45ba-1054-74e4c5a18aa0', 'Petronila', 'Dach', datetime.date(1992, 3, 21), 'white', 'Berkshire County', None, None, 0),
#  ('c30cbd26-0ece-37a8-446f-393bdb373ff1', 'Dwana', 'Cremin', datetime.date(1950, 3, 1), 'white', 'Suffolk County', 'c30cbd26-0ece-37a8-446f-393bdb373ff1', datetime.datetime(2022, 7, 7, 5, 40, 20), 1),
#  ('c191e0bd-681c-5540-e0f6-6eff717c34d0', 'Jaclyn', 'Quitzon', datetime.date(2004, 3, 10), 'white', 'Bristol County', 'c191e0bd-681c-5540-e0f6-6eff717c34d0', datetime.datetime(2022, 5, 4, 11, 37, 51), 1),
#  ('d4129af9-feda-be51-7d48-e96cb3be269d', 'Berna', 'Muller', datetime.date(1987, 1, 24), 'white', 'Middlesex County', None, None, 0),
#  ('350c4803-e018-8e8e-96e8-15e57bbdee44', 'Emmie', 'Brakus', datetime.date(1971, 4, 13), 'white', 'Plymouth County', '350c4803-e018-8e8e-96e8-15e57bbdee44', datetime.datetime(2022, 10, 5, 6, 28, 18), 1),
#  ('d1429c9c-8d4d-c46d-9ff9-89c333a5f809', 'Laureen', 'Heathcote', datetime.date(1998, 4, 9), 'black', 'Essex County', 'd1429c9c-8d4d-c46d-9ff9-89c333a5f809', datetime.datetime(2022, 7, 7, 11, 42, 31), 1),
#  ('86d3afbf-7c87-c13d-774f-04b2d161ded8', 'Branda', 'Hoppe', datetime.date(1999, 3, 30), 'white', 'Barnstable County', '86d3afbf-7c87-c13d-774f-04b2d161ded8', datetime.datetime(2022, 6, 21, 11, 24, 41), 1),
#  ('0fcd6ded-c798-54b7-3b0f-bb4754add211', 'Shona', 'Mayer', datetime.date(1972, 3, 31), 'white', 'Essex County', '0fcd6ded-c798-54b7-3b0f-bb4754add211', datetime.datetime(2022, 11, 12, 4, 18, 53), 1),
#  ('a0a95865-29dc-06af-949b-6474218147fc', 'Aline', 'Beier', datetime.date(1997, 3, 12), 'white', 'Worcester County', 'a0a95865-29dc-06af-949b-6474218147fc', datetime.datetime(2022, 5, 19, 4, 33, 21), 1),
#  ('53e97417-516b-a0a5-c0e0-6883d3b9f677', 'Livia', 'Schmitt', datetime.date(1977, 3, 16), 'white', 'Norfolk County', None, None, 0),
#  ('e77e84e7-ff61-c726-0158-bb7f5ae1cf4a', 'Ozell', 'Keebler', datetime.date(1978, 5, 17), 'white', 'Worcester County', 'e77e84e7-ff61-c726-0158-bb7f5ae1cf4a', datetime.datetime(2022, 6, 1, 11, 28, 19), 1),
#  ('d08ef46d-50b2-36d3-972f-ef54ceea8a69', 'Conchita', 'Urías', datetime.date(1987, 2, 14), 'white', 'Bristol County', None, None, 0),
#  ('0cd38c0a-a7ad-ef52-20dd-ede0dc88833b', 'Freida', 'Goldner', datetime.date(2021, 5, 27), 'white', 'Bristol County', '0cd38c0a-a7ad-ef52-20dd-ede0dc88833b', datetime.datetime(2022, 2, 3, 9, 51, 42), 1),
#  ('8e3e5555-1a4f-f24f-7089-ac3005c24bf4', 'Raymonde', 'Parker', datetime.date(1993, 4, 16), 'white', 'Middlesex County', '8e3e5555-1a4f-f24f-7089-ac3005c24bf4', datetime.datetime(2022, 7, 1, 18, 46, 21), 1),
#  ('c0e61cf1-bba3-dff0-024f-215dcaf23c2d', 'Makeda', 'Murphy', datetime.date(2022, 5, 1), 'asian', 'Hampshire County', None, None, 0),
#  ('554a36c7-f5af-d451-4000-a27a05e8bab5', 'Delila', 'Halvorson', datetime.date(1956, 4, 26), 'white', 'Plymouth County', '554a36c7-f5af-d451-4000-a27a05e8bab5', datetime.datetime(2022, 7, 28, 18, 41, 58), 1),
#  ('b874a563-d3ef-789d-47d4-79c089ec4db4', 'Isabel', 'Esquivel', datetime.date(2011, 2, 24), 'white', 'Hampden County', 'b874a563-d3ef-789d-47d4-79c089ec4db4', datetime.datetime(2022, 3, 10, 22, 1, 24), 1),
#  ('65194cd8-ce59-591a-89b4-bf289590dfb5', 'Tamela', 'Wolff', datetime.date(2021, 1, 16), 'white', 'Norfolk County', '65194cd8-ce59-591a-89b4-bf289590dfb5', datetime.datetime(2022, 12, 24, 11, 24), 1),
#  ('379bb172-8eb1-9b0c-2ece-8c87fbfe009d', 'Julia', 'Kuhic', datetime.date(2008, 4, 4), 'asian', 'Suffolk County', '379bb172-8eb1-9b0c-2ece-8c87fbfe009d', datetime.datetime(2022, 5, 6, 7, 4, 4), 1),
#  ('d8e6a160-6a32-71fb-7625-41ca3bf158a5', 'Junie', 'Pagac', datetime.date(1958, 4, 28), 'white', 'Plymouth County', 'd8e6a160-6a32-71fb-7625-41ca3bf158a5', datetime.datetime(2022, 7, 18, 22, 6, 22), 1),
#  ('809bb039-0a42-35f0-7f56-3e77fae7d78c', 'Lynn', 'Cummerata', datetime.date(1978, 4, 6), 'white', 'Plymouth County', '809bb039-0a42-35f0-7f56-3e77fae7d78c', datetime.datetime(2022, 3, 31, 20, 2, 15), 1),
#  ('590140ad-e102-b74f-c714-0e0c6187bb65', 'Blythe', 'Breitenberg', datetime.date(1975, 4, 27), 'white', 'Middlesex County', '590140ad-e102-b74f-c714-0e0c6187bb65', datetime.datetime(2022, 4, 3, 14, 11, 2), 1),
#  ('0cbebdc9-be8f-cffd-764e-b0572b752695', 'María Teresa', 'Jasso', datetime.date(1954, 3, 3), 'black', 'Suffolk County', '0cbebdc9-be8f-cffd-764e-b0572b752695', datetime.datetime(2022, 11, 30, 14, 45, 41), 1),
#  ('4f2ec387-f0b9-ddce-acf0-acafbc8819e4', 'Dorris', 'Zboncak', datetime.date(2001, 1, 30), 'white', 'Hampshire County', '4f2ec387-f0b9-ddce-acf0-acafbc8819e4', datetime.datetime(2022, 5, 31, 19, 55, 55), 1),
#  ('5c876831-e0c1-5315-f741-4867c56983c9', 'So', 'Hintz', datetime.date(2014, 5, 28), 'white', 'Suffolk County', '5c876831-e0c1-5315-f741-4867c56983c9', datetime.datetime(2022, 5, 26, 2, 8, 20), 1),
#  ('7d3f18e1-8f3c-4149-39f8-5c6566b9cb41', 'Delphia', 'Goldner', datetime.date(1993, 3, 9), 'white', 'Worcester County', None, None, 0),
#  ('d7b125aa-b0e1-b93d-ffc0-734424e78ff5', 'Lannie', 'Nicolas', datetime.date(2008, 2, 13), 'white', 'Essex County', 'd7b125aa-b0e1-b93d-ffc0-734424e78ff5', datetime.datetime(2022, 3, 16, 15, 53, 27), 1),
#  ('32a721b8-ea34-7d17-0a2e-c7b81becdf35', 'Ginette', 'Quitzon', datetime.date(1974, 1, 12), 'white', 'Middlesex County', '32a721b8-ea34-7d17-0a2e-c7b81becdf35', datetime.datetime(2022, 7, 2, 12, 29, 50), 1),
#  ('019bb246-908b-66c8-9b5a-a220c36ba631', 'Rea', 'Blanda', datetime.date(1976, 3, 5), 'white', 'Worcester County', '019bb246-908b-66c8-9b5a-a220c36ba631', datetime.datetime(2022, 4, 1, 16, 55, 24), 1),
#  ('a2bde5d7-cbee-f5c8-41c3-c0a662529213', 'Carmelita', 'Huels', datetime.date(1950, 2, 7), 'white', 'Bristol County', 'a2bde5d7-cbee-f5c8-41c3-c0a662529213', datetime.datetime(2022, 6, 14, 22, 53, 30), 1),
#  ('4bcce5b0-eca7-e6b9-6656-17996c88fc78', 'Yvone', 'Collins', datetime.date(1981, 5, 29), 'white', 'Bristol County', '4bcce5b0-eca7-e6b9-6656-17996c88fc78', datetime.datetime(2022, 11, 4, 12, 19, 36), 1),
#  ('bb40a069-a407-8a4b-dee6-7e81843a0a38', 'Millicent', 'Kertzmann', datetime.date(1996, 4, 1), 'asian', 'Suffolk County', None, None, 0),
#  ('7592ad11-4afd-090f-9a21-06ef5744b1dc', 'Kathyrn', 'Huel', datetime.date(2017, 5, 12), 'white', 'Plymouth County', '7592ad11-4afd-090f-9a21-06ef5744b1dc', datetime.datetime(2022, 4, 22, 14, 0, 10), 1),
#  ('e3b064f3-af2f-45f6-3108-9e3d7dbdfe64', 'Lessie', 'Wehner', datetime.date(1967, 5, 25), 'white', 'Barnstable County', 'e3b064f3-af2f-45f6-3108-9e3d7dbdfe64', datetime.datetime(2022, 6, 23, 13, 12, 15), 1),
#  ('910d5a50-0f86-9aa4-ee24-c3ee2aef4c43', 'Charleen', 'Swift', datetime.date(1940, 3, 31), 'white', 'Worcester County', '910d5a50-0f86-9aa4-ee24-c3ee2aef4c43', datetime.datetime(2022, 10, 2, 22, 42, 8), 1),
#  ('49a9f1de-4262-57b5-24d0-2f8f1cf818d8', 'Shaquita', 'Hodkiewicz', datetime.date(1981, 2, 3), 'white', 'Essex County', '49a9f1de-4262-57b5-24d0-2f8f1cf818d8', datetime.datetime(2022, 5, 25, 4, 55, 8), 1),
#  ('ef420eeb-3d1f-b5b5-35bc-eb5a598fa7d6', 'Oliva', 'Volkman', datetime.date(1991, 3, 7), 'black', 'Hampden County', 'ef420eeb-3d1f-b5b5-35bc-eb5a598fa7d6', datetime.datetime(2022, 7, 1, 2, 9, 51), 1),
#  ('0823764d-e155-de87-f0d5-1cac01502c33', 'Jessika', 'Cremin', datetime.date(1990, 3, 26), 'white', 'Franklin County', '0823764d-e155-de87-f0d5-1cac01502c33', datetime.datetime(2022, 4, 4, 22, 2, 43), 1),
#  ('12b4e87d-9cae-579a-15df-891788856954', 'Tula', 'Reichert', datetime.date(1963, 5, 7), 'white', 'Barnstable County', '12b4e87d-9cae-579a-15df-891788856954', datetime.datetime(2022, 6, 28, 15, 23, 5), 1),
#  ('9045c84d-7b27-5721-ce65-2b34a2d24555', 'Bev', 'Schneider', datetime.date(1987, 5, 27), 'asian', 'Middlesex County', None, None, 0),
#  ('0f5c101e-371b-0df7-78f2-b4cf8f2e8168', 'Florine', 'Blanda', datetime.date(1966, 1, 10), 'black', 'Suffolk County', '0f5c101e-371b-0df7-78f2-b4cf8f2e8168', datetime.datetime(2022, 8, 29, 21, 27, 7), 1),
#  ('d01e4339-1dd5-7ff5-a040-04ad08ce98d3', 'Joannie', 'Auer', datetime.date(1990, 3, 6), 'white', 'Bristol County', 'd01e4339-1dd5-7ff5-a040-04ad08ce98d3', datetime.datetime(2022, 6, 8, 3, 12, 8), 1),
#  ('628dc920-eb4b-0049-25b2-9ea3354930a4', 'Fallon', 'Schamberger', datetime.date(1947, 4, 19), 'white', 'Norfolk County', '628dc920-eb4b-0049-25b2-9ea3354930a4', datetime.datetime(2022, 7, 30, 15, 43, 38), 1),
#  ('3941bf58-e589-814c-556d-aa90f2fb2ebf', 'Marx', 'Kunze', datetime.date(1940, 5, 5), 'white', 'Bristol County', '3941bf58-e589-814c-556d-aa90f2fb2ebf', datetime.datetime(2022, 11, 6, 20, 28, 30), 1),
#  ('cdacbe7c-5779-4fd2-ed8b-482d6ddfde40', 'Nannette', 'Gutmann', datetime.date(2009, 1, 28), 'asian', 'Norfolk County', 'cdacbe7c-5779-4fd2-ed8b-482d6ddfde40', datetime.datetime(2022, 2, 23, 14, 21, 31), 1),
#  ('c82bb121-88d9-3eef-1fc2-f40d6a26c0fc', 'Sena', "O'Conner", datetime.date(1966, 1, 26), 'white', 'Hampden County', 'c82bb121-88d9-3eef-1fc2-f40d6a26c0fc', datetime.datetime(2022, 8, 18, 6, 29, 27), 1),
#  ('9284e36d-9171-003c-2cf5-a1b81ea3a5c8', 'Sharlene', "O'Conner", datetime.date(1946, 2, 3), 'white', 'Worcester County', '9284e36d-9171-003c-2cf5-a1b81ea3a5c8', datetime.datetime(2022, 8, 14, 18, 38, 12), 1),
#  ('c413a7f2-d1d2-0981-0f76-803ffb0b88d3', 'Sherita', 'Jerde', datetime.date(1957, 2, 14), 'white', 'Worcester County', 'c413a7f2-d1d2-0981-0f76-803ffb0b88d3', datetime.datetime(2022, 5, 13, 6, 59, 50), 1),
#  ('25de6f03-7a4a-814c-cfed-27f76c0f8c7e', 'Francene', 'Kunde', datetime.date(1986, 2, 14), 'white', 'Bristol County', None, None, 0),
#  ('51b38bd3-da1c-cabe-284b-3fe242dc88f1', 'Melinda', 'Quigley', datetime.date(1970, 1, 7), 'white', 'Worcester County', '51b38bd3-da1c-cabe-284b-3fe242dc88f1', datetime.datetime(2022, 2, 23, 19, 47, 13), 1),
#  ('c22107ee-7864-5d9d-b327-01b213f913a4', 'María Luisa', 'Paredes', datetime.date(2019, 3, 15), 'white', 'Bristol County', 'c22107ee-7864-5d9d-b327-01b213f913a4', datetime.datetime(2022, 2, 18, 16, 48, 27), 1),
#  ...]

# %%
# %%sql
